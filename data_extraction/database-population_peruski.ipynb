# %%
import pandas as pd
from datetime import date, timedelta
import nba_api.stats.endpoints as endpoints
from nba_api.live.nba.endpoints import boxscore

# %% [markdown]
# ### Helper Functions
# - Testing for these functions in data_extraction/nba-api-demo.ipynb

# %%
from nba_api.stats.endpoints import boxscoresummaryv2

def get_home_away_team(game_id):
    """
    Retrieves the home and away team IDs for a given NBA game.

    Parameters:
    game_id (str): The unique identifier for the game.

    Returns:
    tuple: A pair of integers representing the home team ID and away team ID.
    """

    boxscore = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id)
    game_data = boxscore.get_data_frames()[0]  # Game summary data

    home_team_id = game_data['HOME_TEAM_ID'].iloc[0]  # Extract home team ID
    away_team_id = game_data['VISITOR_TEAM_ID'].iloc[0]  # Extract away team ID

    return home_team_id, away_team_id

# %%
def get_season(game_id):
    """
    Determines the NBA season based on the given game_id.

    The game_id follows a pattern where:
    - A game_id starting with '00246' to '00299' corresponds to seasons from 1946-47 to 1999-00.
    - A game_id starting with '00200' to '00224' corresponds to seasons from 2000-01 to 2024-25.

    Logic:
    - Extract the 4th and 5th digits of game_id (game_year).
    - If game_year is between 46 and 99, it belongs to the 1900s (1946-47 to 1999-00).
    - Otherwise, it belongs to the 2000s (2000-01 onward).
    - The output is formatted as "YYYY-YY", where YY represents the last two digits of the next year.

    Parameters:
    game_id (str): The unique identifier for the game.

    Returns:
    string: The NBA season in the format 'YYYY-YY' (e.g., '1999-00').
    """

    game_year = int(game_id[3:5])  # Extracts the season identifier
    if 46 <= game_year <= 99:
        start_year = game_year + 1900
    else:
        start_year = game_year + 2000

    end_year_short = (start_year + 1) % 100  # Get last two digits of the next year
    return f"{start_year}-{end_year_short:02d}"

# %% [markdown]
# ### Populating the Teams Table

# %%
def fill_teams_df(game_id, team_stats, teams_df):

    season_year = get_season(game_id)
    team_ids = team_stats['TEAM_ID'].unique()

    # Get home team data
    team_one_row = team_stats[team_stats['TEAM_ID'] == team_ids[0]].iloc[0]
    team_one_location = team_one_row['TEAM_CITY']
    team_one_name = team_one_row['TEAM_NAME']
    team_one_abbrev = team_one_row['TEAM_ABBREVIATION']

    # Get away team data
    team_two_row = team_stats[team_stats['TEAM_ID'] == team_ids[1]].iloc[0]
    team_two_location = team_two_row['TEAM_CITY']
    team_two_name = team_two_row['TEAM_NAME']
    team_two_abbrev = team_two_row['TEAM_ABBREVIATION']

    # Convert the data to a data frame and concatenate it with the existing teams_df
    new_rows = pd.DataFrame([
        {'team_id': team_ids[0], 'season_year': season_year,
        'team_location': team_one_location, 'team_name': team_one_name,
        'team_abbreviation': team_one_abbrev},

        {'team_id': team_ids[1], 'season_year': season_year,
        'team_location': team_two_location, 'team_name': team_two_name,
        'team_abbreviation': team_two_abbrev}
    ])

    # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
    existing_keys = set(zip(teams_df['team_id'], teams_df['season_year']))
    new_rows_filtered = new_rows[~new_rows.apply(lambda row: (row['team_id'], row['season_year']) in existing_keys, axis=1)]

    # Concatenate only if new unique rows exist
    if not new_rows_filtered.empty:
        teams_df = pd.concat([teams_df, new_rows_filtered], ignore_index=True)

    return teams_df

# %%
def fill_players_df(player_stats, players_df):

    player_ids = player_stats['PLAYER_ID'].unique()

    for player_id in player_ids:
        # Get the player data
        player_row = player_stats[player_stats['PLAYER_ID'] == player_id].iloc[0]
        full_name = player_row['PLAYER_NAME']
        name_parts = full_name.split(" ", 1)  # Split at the first space
        player_first_name = name_parts[0]  # First name (everything before the first space)
        player_last_name = name_parts[1] if len(name_parts) > 1 else ""  # Last name (everything after), or empty if no space

        # Convert the data to a data frame and concatenate it with the existing players_df
        new_row = pd.DataFrame([
            {'player_id': player_id,
            'player_first_name': player_first_name, 'player_last_name': player_last_name
            },
        ])

        # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
        existing_keys = set(zip(players_df['player_id']))
        new_rows_filtered = new_row[~new_row.apply(lambda row: (row['player_id']) in existing_keys, axis=1)]

        # Concatenate only if new unique rows exist
        if not new_rows_filtered.empty:
            players_df = pd.concat([players_df, new_rows_filtered], ignore_index=True)

    return players_df

# %%
def fill_games_df(game_id, game_date, games_df):
    season_year = get_season(game_id)
    home_team_id, away_team_id = get_home_away_team(game_id)

    # Convert the data to a data frame and concatenate it with the existing games_df
    new_row = pd.DataFrame([
        {'game_id': game_id, 'season_year': season_year, 'game_date': game_date,
        'home_team_id': home_team_id, 'away_team_id': away_team_id}
    ])

    # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
    existing_keys = set(zip(games_df['game_id'], games_df['season_year']))
    new_rows_filtered = new_row[~new_row.apply(lambda row: (row['game_id'], row['season_year']) in existing_keys, axis=1)]

    # Concatenate only if new unique rows exist
    if not new_rows_filtered.empty:
        games_df = pd.concat([games_df, new_rows_filtered], ignore_index=True)

    return games_df

# %%
def get_player_game_stats(game_id, player_stats, player_game_stats_df):
    player_ids = player_stats['PLAYER_ID'].unique()

    columns_to_keep = [
        "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", 
        "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", 
        "BLK", "TO", "PF", "PTS", "PLUS_MINUS"
    ]

    for player_id in player_ids:
        player_row = player_stats[player_stats['PLAYER_ID'] == player_id].iloc[0]

        # Get the player stats in JSON format
        player_stats_json = player_row.to_dict()

        # Filter the data
        player_stats_json = [
            {key: player_stats_json[key] for key in columns_to_keep if key in player_stats_json} 
        ]

        # Convert the data to a data frame and concatenate it with the existing player_game_stats_df
        new_row = pd.DataFrame([
            {'game_id': game_id, 'player_id': player_id, 'team_id': player_row['TEAM_ID'], 
            'player_game_stats': player_stats_json}
        ])

        # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
        existing_keys = set(zip(player_game_stats_df['game_id'], player_game_stats_df['player_id']))
        new_rows_filtered = new_row[~new_row.apply(lambda row: (row['game_id'], row['player_id']) in existing_keys, axis=1)]

        # Concatenate only if new unique rows exist
        if not new_rows_filtered.empty:
            player_game_stats_df = pd.concat([player_game_stats_df, new_rows_filtered], ignore_index=True)

    return player_game_stats_df

# %%
import time
import random
from datetime import date, timedelta
import pandas as pd

# Initialize DataFrames
teams_df = pd.DataFrame(columns=['team_id', 'season_year', 'team_location', 'team_name', 'team_abbreviation'])
players_df = pd.DataFrame(columns=['player_id', 'player_first_name', 'player_last_name'])
games_df = pd.DataFrame(columns=['game_id', 'season_year', 'game_date', 'home_team_id', 'away_team_id'])
player_game_stats_df = pd.DataFrame(columns=['game_id', 'player_id', 'team_id', 'player_game_stats'])

start_date = date(2023, 3, 26)
end_date = date(2024, 4, 14)

current_date = start_date
current_highest_season = ""

# Function to simulate an API request with retries and exponential backoff
def fetch_with_retry(func, *args, **kwargs):
    retries = 20  # Number of retries
    delay = 1  # Initial delay time in seconds
    for attempt in range(retries):
        try:
            # Call the original function with passed arguments and keyword arguments
            return func(*args, **kwargs)
        except Exception as e:
            if attempt < retries - 1:
                print(f"Error inside retry fn: {e}. Retrying in {delay}s...")
                #print the current time
                print(time.strftime('%X %x %Z'))
                time.sleep(delay)
                delay *= 2  # Exponential backoff
            else:
                print(f"Failed after {retries} attempts: {e}")
                return None

# Request limit settings
delay_between_requests = 1  # Start with a 60-second delay (1 request per minute)
max_delay = 360  # Maximum delay of 6 minutes (to prevent overwhelming the server)

while current_date <= end_date:
    print(f"Processing games for {current_date}...")
    
    # Add a random sleep time to avoid hitting rate limits
    time.sleep(random.uniform(1.0, 2.0))
    
    # Fetch the games data with retry and exponential backoff
    games = fetch_with_retry(endpoints.scoreboardv2.ScoreboardV2, game_date=current_date)
    
    if games is None:
        # If the fetch failed after retries, skip this date
        start_date += timedelta(days=1)
        print(f"Failed to fetch games for {current_date}. Skipping.")
        continue
    
    try:
        games_data = games.get_data_frames()[0]
        game_ids = games_data['GAME_ID']

        if len(game_ids) > 0:
            current_highest_season = get_season(game_ids[0])  # Assuming get_season is defined somewhere
        else:
            print(f"No games found for {current_date}")
    except Exception as e:
        print(f"Error processing games for {current_date}: {e}. Skipping")
        start_date += timedelta(days=1)
        continue
    
    # Loop through all the game IDs and fetch the box score data
    for game_id in game_ids:
        # Get all stats using BoxScoreTraditionalV2 with retry and exponential backoff
        while True:
            boxscore = fetch_with_retry(endpoints.boxscoretraditionalv2.BoxScoreTraditionalV2, game_id=game_id)
            
            if boxscore is None:
                print(f"Error fetching stats for game {game_id} -- boxscore is None. Tryinhg again")
                continue

            try:
                player_stats = boxscore.get_data_frames()[0]
                team_stats = boxscore.get_data_frames()[1]
                
                teams_df = fill_teams_df(game_id, team_stats, teams_df)
                players_df = fill_players_df(player_stats, players_df)
                games_df = fill_games_df(game_id, current_date, games_df)
                player_game_stats_df = get_player_game_stats(game_id, player_stats, player_game_stats_df)

                teams_df.to_csv(f'teams-old-2.csv', index=False)
                players_df.to_csv(f'players-old-2.csv', index=False)
                games_df.to_csv(f'games-old-2.csv', index=False)
                player_game_stats_df.to_csv(f'player_game_stats-old-2.csv', index=False)
                print(f"Processed game {game_id} for date {current_date}.")

                break


            except Exception as e:
                print(f"Error processing stats for game {game_id}: {e}. Trying Again")
                continue

    # After processing all games, move to the next 1 days
    current_date += timedelta(days=1)

    # Implement request throttling based on rate limits
    time.sleep(delay_between_requests + random.uniform(0, 1))  # Adding a bit of randomness to avoid clustered requests

    # Apply exponential backoff: increase delay after each request to manage rate limits
    delay_between_requests = min(delay_between_requests, max_delay)

# print(teams_df)
# print('\n')
# print(players_df)
# print('\n')
# print(games_df)
# print('\n')
# print(player_game_stats_df)

print(len(games_df.game_id.unique()), "games processed")
print(len(player_game_stats_df.game_id.unique()), "unique games with player stats")
# Out:
# Processing games for 2023-03-26...
# Processed game 0022201113 for date 2023-03-26.
# Processed game 0022201114 for date 2023-03-26.
# Processed game 0022201115 for date 2023-03-26.
# Processed game 0022201116 for date 2023-03-26.
# Processed game 0022201117 for date 2023-03-26.
# Processed game 0022201118 for date 2023-03-26.
# Processed game 0022201119 for date 2023-03-26.
# Processed game 0022201120 for date 2023-03-26.
# Processed game 0022201121 for date 2023-03-26.
# Processing games for 2023-03-27...
# Processed game 0022201122 for date 2023-03-27.
# Processed game 0022201123 for date 2023-03-27.
# Processed game 0022201124 for date 2023-03-27.
# Processed game 0022201125 for date 2023-03-27.
# Processed game 0022201126 for date 2023-03-27.
# Processed game 0022201127 for date 2023-03-27.
# Processed game 0022201128 for date 2023-03-27.
# Processed game 0022201129 for date 2023-03-27.
# Processing games for 2023-03-28...
# Processed game 0022201130 for date 2023-03-28.
# Processed game 0022201131 for date 2023-03-28.
# Processed game 0022201132 for date 2023-03-28.
# Processed game 0022201133 for date 2023-03-28.
# Processed game 0022201134 for date 2023-03-28.
# Processed game 0022201135 for date 2023-03-28.
# Processing games for 2023-03-29...
# Processed game 0022201136 for date 2023-03-29.
# Processed game 0022201137 for date 2023-03-29.
# Processed game 0022201138 for date 2023-03-29.
# Processed game 0022201139 for date 2023-03-29.
# Processed game 0022201140 for date 2023-03-29.
# Processed game 0022201141 for date 2023-03-29.
# Processed game 0022201142 for date 2023-03-29.
# Processed game 0022201143 for date 2023-03-29.
# Processed game 0022201144 for date 2023-03-29.
# Processed game 0022201145 for date 2023-03-29.
# Processing games for 2023-03-30...
# Processed game 0022201146 for date 2023-03-30.
# Processed game 0022201147 for date 2023-03-30.
# Processing games for 2023-03-31...
# Processed game 0022201148 for date 2023-03-31.
# Processed game 0022201149 for date 2023-03-31.
# Processed game 0022201150 for date 2023-03-31.
# Processed game 0022201151 for date 2023-03-31.
# Processed game 0022201152 for date 2023-03-31.
# Processed game 0022201153 for date 2023-03-31.
# Processed game 0022201154 for date 2023-03-31.
# Processed game 0022201155 for date 2023-03-31.
# Processed game 0022201156 for date 2023-03-31.
# Processed game 0022201157 for date 2023-03-31.
# Processed game 0022201158 for date 2023-03-31.
# Processed game 0022201159 for date 2023-03-31.
# Processed game 0022201160 for date 2023-03-31.
# Processing games for 2023-04-01...
# Processed game 0022201161 for date 2023-04-01.
# Processed game 0022201162 for date 2023-04-01.
# Processing games for 2023-04-02...
# Processed game 0022201163 for date 2023-04-02.
# Processed game 0022201164 for date 2023-04-02.
# Processed game 0022201165 for date 2023-04-02.
# Processed game 0022201166 for date 2023-04-02.
# Processed game 0022201167 for date 2023-04-02.
# Processed game 0022201168 for date 2023-04-02.
# Processed game 0022201169 for date 2023-04-02.
# Processed game 0022201170 for date 2023-04-02.
# Processed game 0022201171 for date 2023-04-02.
# Processed game 0022201172 for date 2023-04-02.
# Processed game 0022201173 for date 2023-04-02.
# Processed game 0022201174 for date 2023-04-02.
# Processed game 0022201175 for date 2023-04-02.
# Processing games for 2023-04-03...
# No games found for 2023-04-03
# Processing games for 2023-04-04...
# Processed game 0022201176 for date 2023-04-04.
# Processed game 0022201177 for date 2023-04-04.
# Processed game 0022201178 for date 2023-04-04.
# Processed game 0022201179 for date 2023-04-04.
# Processed game 0022201180 for date 2023-04-04.
# Processed game 0022201181 for date 2023-04-04.
# Processed game 0022201182 for date 2023-04-04.
# Processed game 0022201183 for date 2023-04-04.
# Processed game 0022201184 for date 2023-04-04.
# Processed game 0022201185 for date 2023-04-04.
# Processed game 0022201186 for date 2023-04-04.
# Processed game 0022201187 for date 2023-04-04.
# Processed game 0022201188 for date 2023-04-04.
# Processing games for 2023-04-05...
# Processed game 0022201189 for date 2023-04-05.
# Processed game 0022201190 for date 2023-04-05.
# Processed game 0022201191 for date 2023-04-05.
# Processed game 0022201192 for date 2023-04-05.
# Processed game 0022201193 for date 2023-04-05.
# Processed game 0022201194 for date 2023-04-05.
# Processed game 0022201195 for date 2023-04-05.
# Processed game 0022201196 for date 2023-04-05.
# Processing games for 2023-04-06...
# Processed game 0022201197 for date 2023-04-06.
# Processed game 0022201198 for date 2023-04-06.
# Processed game 0022201199 for date 2023-04-06.
# Processed game 0022201200 for date 2023-04-06.
# Processed game 0022201201 for date 2023-04-06.
# Processing games for 2023-04-07...
# Processed game 0022201202 for date 2023-04-07.
# Processed game 0022201203 for date 2023-04-07.
# Processed game 0022201204 for date 2023-04-07.
# Processed game 0022201205 for date 2023-04-07.
# Processed game 0022201206 for date 2023-04-07.
# Processed game 0022201207 for date 2023-04-07.
# Processed game 0022201208 for date 2023-04-07.
# Processed game 0022201209 for date 2023-04-07.
# Processed game 0022201210 for date 2023-04-07.
# Processed game 0022201211 for date 2023-04-07.
# Processed game 0022201212 for date 2023-04-07.
# Processing games for 2023-04-08...
# Processed game 0022201213 for date 2023-04-08.
# Processed game 0022201214 for date 2023-04-08.
# Processed game 0022201215 for date 2023-04-08.
# Processing games for 2023-04-09...
# Processed game 0022201216 for date 2023-04-09.
# Processed game 0022201217 for date 2023-04-09.
# Processed game 0022201218 for date 2023-04-09.
# Processed game 0022201219 for date 2023-04-09.
# Processed game 0022201220 for date 2023-04-09.
# Processed game 0022201221 for date 2023-04-09.
# Processed game 0022201222 for date 2023-04-09.
# Processed game 0022201223 for date 2023-04-09.
# Processed game 0022201224 for date 2023-04-09.
# Processed game 0022201225 for date 2023-04-09.
# Processed game 0022201226 for date 2023-04-09.
# Processed game 0022201227 for date 2023-04-09.
# Processed game 0022201228 for date 2023-04-09.
# Processed game 0022201229 for date 2023-04-09.
# Processed game 0022201230 for date 2023-04-09.
# Processing games for 2023-04-10...
# No games found for 2023-04-10
# Processing games for 2023-04-11...
# Processed game 0052200101 for date 2023-04-11.
# Processed game 0052200121 for date 2023-04-11.
# Processing games for 2023-04-12...
# Processed game 0052200111 for date 2023-04-12.
# Processed game 0052200131 for date 2023-04-12.
# Processing games for 2023-04-13...
# No games found for 2023-04-13
# Processing games for 2023-04-14...
# Processed game 0052200201 for date 2023-04-14.
# Processed game 0052200211 for date 2023-04-14.
# Processing games for 2023-04-15...
# Processed game 0042200121 for date 2023-04-15.
# Processed game 0042200111 for date 2023-04-15.
# Processed game 0042200131 for date 2023-04-15.
# Processed game 0042200161 for date 2023-04-15.
# Processing games for 2023-04-16...
# Processed game 0042200151 for date 2023-04-16.
# Processed game 0042200101 for date 2023-04-16.
# Processed game 0042200171 for date 2023-04-16.
# Processed game 0042200141 for date 2023-04-16.
# Processing games for 2023-04-17...
# Processed game 0042200122 for date 2023-04-17.
# Processed game 0042200162 for date 2023-04-17.
# Processing games for 2023-04-18...
# Processed game 0042200112 for date 2023-04-18.
# Processed game 0042200132 for date 2023-04-18.
# Processed game 0042200172 for date 2023-04-18.
# Processing games for 2023-04-19...
# Processed game 0042200152 for date 2023-04-19.
# Processed game 0042200102 for date 2023-04-19.
# Processed game 0042200142 for date 2023-04-19.
# Processing games for 2023-04-20...
# Processed game 0042200123 for date 2023-04-20.
# Processed game 0042200163 for date 2023-04-20.
# Processed game 0042200173 for date 2023-04-20.
# Processing games for 2023-04-21...
# Processed game 0042200113 for date 2023-04-21.
# Processed game 0042200133 for date 2023-04-21.
# Processed game 0042200143 for date 2023-04-21.
# Processing games for 2023-04-22...
# Processed game 0042200124 for date 2023-04-22.
# Processed game 0042200174 for date 2023-04-22.
# Processed game 0042200103 for date 2023-04-22.
# Processed game 0042200153 for date 2023-04-22.
# Processing games for 2023-04-23...
# Processed game 0042200134 for date 2023-04-23.
# Processed game 0042200164 for date 2023-04-23.
# Processed game 0042200114 for date 2023-04-23.
# Processed game 0042200144 for date 2023-04-23.
# Processing games for 2023-04-24...
# Processed game 0042200104 for date 2023-04-24.
# Processed game 0042200154 for date 2023-04-24.
# Processing games for 2023-04-25...
# Processed game 0042200115 for date 2023-04-25.
# Processed game 0042200145 for date 2023-04-25.
# Processed game 0042200175 for date 2023-04-25.
# Processing games for 2023-04-26...
# Processed game 0042200135 for date 2023-04-26.
# Processed game 0042200155 for date 2023-04-26.
# Processed game 0042200105 for date 2023-04-26.
# Processed game 0042200165 for date 2023-04-26.
# Processing games for 2023-04-27...
# Processed game 0042200116 for date 2023-04-27.
# Processing games for 2023-04-28...
# Processed game 0042200166 for date 2023-04-28.
# Processed game 0042200156 for date 2023-04-28.
# Processing games for 2023-04-29...
# Processed game 0042200221 for date 2023-04-29.
# Processing games for 2023-04-30...
# Processed game 0042200201 for date 2023-04-30.
# Processed game 0042200167 for date 2023-04-30.
# Processing games for 2023-05-01...
# Processed game 0042200211 for date 2023-05-01.
# Processed game 0042200222 for date 2023-05-01.
# Processing games for 2023-05-02...
# Processed game 0042200202 for date 2023-05-02.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 17:24:29 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 2s...
# 17:24:58 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 17:25:30 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 17:26:05 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 17:26:43 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 17:27:30 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 17:28:32 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 128s...
# 17:30:02 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 256s...
# 17:32:37 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 17:37:23 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1024s...
# 17:46:17 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 18:03:51 03/27/25 Eastern Daylight Time
# Processed game 0012300051 for date 2023-10-17.
# Processed game 0012300052 for date 2023-10-17.
# Processed game 0012300053 for date 2023-10-17.
# Processed game 0012300054 for date 2023-10-17.
# Processed game 0012300055 for date 2023-10-17.
# Processing games for 2023-10-18...
# Processed game 0012300056 for date 2023-10-18.
# Processed game 0012300057 for date 2023-10-18.
# Processed game 0012300058 for date 2023-10-18.
# Processed game 0012300059 for date 2023-10-18.
# Processing games for 2023-10-19...
# Processed game 0012300060 for date 2023-10-19.
# Processed game 0012300061 for date 2023-10-19.
# Processed game 0012300062 for date 2023-10-19.
# Processed game 0012300063 for date 2023-10-19.
# Processed game 0012300064 for date 2023-10-19.
# Processed game 0012300065 for date 2023-10-19.
# Processing games for 2023-10-20...
# Processed game 0012300066 for date 2023-10-20.
# Processed game 0012300067 for date 2023-10-20.
# Processed game 0012300068 for date 2023-10-20.
# Processed game 0012300069 for date 2023-10-20.
# Processed game 0012300070 for date 2023-10-20.
# Processed game 0012300071 for date 2023-10-20.
# Processed game 0012300072 for date 2023-10-20.
# Processed game 0012300073 for date 2023-10-20.
# Processing games for 2023-10-21...
# No games found for 2023-10-21
# Processing games for 2023-10-22...
# No games found for 2023-10-22
# Processing games for 2023-10-23...
# No games found for 2023-10-23
# Processing games for 2023-10-24...
# Processed game 0022300061 for date 2023-10-24.
# Processed game 0022300062 for date 2023-10-24.
# Processing games for 2023-10-25...
# Processed game 0022300063 for date 2023-10-25.
# Processed game 0022300064 for date 2023-10-25.
# Processed game 0022300065 for date 2023-10-25.
# Processed game 0022300066 for date 2023-10-25.
# Processed game 0022300067 for date 2023-10-25.
# Processed game 0022300068 for date 2023-10-25.
# Processed game 0022300069 for date 2023-10-25.
# Processed game 0022300070 for date 2023-10-25.
# Processed game 0022300071 for date 2023-10-25.
# Processed game 0022300072 for date 2023-10-25.
# Processed game 0022300073 for date 2023-10-25.
# Processed game 0022300074 for date 2023-10-25.
# Processing games for 2023-10-26...
# Processed game 0022300075 for date 2023-10-26.
# Processed game 0022300076 for date 2023-10-26.
# Processing games for 2023-10-27...
# Processed game 0022300077 for date 2023-10-27.
# Processed game 0022300078 for date 2023-10-27.
# Processed game 0022300079 for date 2023-10-27.
# Processed game 0022300080 for date 2023-10-27.
# Processed game 0022300081 for date 2023-10-27.
# Processed game 0022300082 for date 2023-10-27.
# Processed game 0022300083 for date 2023-10-27.
# Processed game 0022300084 for date 2023-10-27.
# Processed game 0022300085 for date 2023-10-27.
# Processed game 0022300086 for date 2023-10-27.
# Processed game 0022300087 for date 2023-10-27.
# Processing games for 2023-10-28...
# Processed game 0022300088 for date 2023-10-28.
# Processed game 0022300089 for date 2023-10-28.
# Processed game 0022300090 for date 2023-10-28.
# Processed game 0022300091 for date 2023-10-28.
# Processed game 0022300092 for date 2023-10-28.
# Processed game 0022300093 for date 2023-10-28.
# Processed game 0022300094 for date 2023-10-28.
# Processing games for 2023-10-29...
# Processed game 0022300095 for date 2023-10-29.
# Processed game 0022300096 for date 2023-10-29.
# Processed game 0022300097 for date 2023-10-29.
# Processed game 0022300098 for date 2023-10-29.
# Processed game 0022300099 for date 2023-10-29.
# Processed game 0022300100 for date 2023-10-29.
# Processing games for 2023-10-30...
# Processed game 0022300101 for date 2023-10-30.
# Processed game 0022300102 for date 2023-10-30.
# Processed game 0022300103 for date 2023-10-30.
# Processed game 0022300104 for date 2023-10-30.
# Processed game 0022300105 for date 2023-10-30.
# Processed game 0022300106 for date 2023-10-30.
# Processed game 0022300107 for date 2023-10-30.
# Processed game 0022300108 for date 2023-10-30.
# Processed game 0022300109 for date 2023-10-30.
# Processed game 0022300110 for date 2023-10-30.
# Processed game 0022300111 for date 2023-10-30.
# Processing games for 2023-10-31...
# Processed game 0022300112 for date 2023-10-31.
# Processed game 0022300113 for date 2023-10-31.
# Processed game 0022300114 for date 2023-10-31.
# Processing games for 2023-11-01...
# Processed game 0022300115 for date 2023-11-01.
# Processed game 0022300116 for date 2023-11-01.
# Processed game 0022300117 for date 2023-11-01.
# Processed game 0022300118 for date 2023-11-01.
# Processed game 0022300119 for date 2023-11-01.
# Processed game 0022300120 for date 2023-11-01.
# Processed game 0022300121 for date 2023-11-01.
# Processed game 0022300122 for date 2023-11-01.
# Processed game 0022300123 for date 2023-11-01.
# Processed game 0022300124 for date 2023-11-01.
# Processed game 0022300125 for date 2023-11-01.
# Processed game 0022300126 for date 2023-11-01.
# Processed game 0022300127 for date 2023-11-01.
# Processing games for 2023-11-02...
# Processed game 0022300128 for date 2023-11-02.
# Processed game 0022300129 for date 2023-11-02.
# Processed game 0022300130 for date 2023-11-02.
# Processed game 0022300131 for date 2023-11-02.
# Processing games for 2023-11-03...
# Processed game 0022300001 for date 2023-11-03.
# Processed game 0022300002 for date 2023-11-03.
# Processed game 0022300003 for date 2023-11-03.
# Processed game 0022300004 for date 2023-11-03.
# Processed game 0022300005 for date 2023-11-03.
# Processed game 0022300006 for date 2023-11-03.
# Processed game 0022300007 for date 2023-11-03.
# Processing games for 2023-11-04...
# Processed game 0022300132 for date 2023-11-04.
# Processed game 0022300133 for date 2023-11-04.
# Processed game 0022300134 for date 2023-11-04.
# Processed game 0022300135 for date 2023-11-04.
# Processed game 0022300136 for date 2023-11-04.
# Processed game 0022300137 for date 2023-11-04.
# Processed game 0022300138 for date 2023-11-04.
# Processed game 0022300139 for date 2023-11-04.
# Processing games for 2023-11-05...
# Processed game 0022300140 for date 2023-11-05.
# Processed game 0022300141 for date 2023-11-05.
# Processed game 0022300142 for date 2023-11-05.
# Processed game 0022300143 for date 2023-11-05.
# Processed game 0022300144 for date 2023-11-05.
# Processing games for 2023-11-06...
# Processed game 0022300145 for date 2023-11-06.
# Processed game 0022300146 for date 2023-11-06.
# Processed game 0022300147 for date 2023-11-06.
# Processed game 0022300148 for date 2023-11-06.
# Processed game 0022300149 for date 2023-11-06.
# Processed game 0022300150 for date 2023-11-06.
# Processed game 0022300151 for date 2023-11-06.
# Processed game 0022300152 for date 2023-11-06.
# Processed game 0022300153 for date 2023-11-06.
# Processed game 0022300154 for date 2023-11-06.
# Processed game 0022300155 for date 2023-11-06.
# Processed game 0022300156 for date 2023-11-06.
# Processing games for 2023-11-07...
# No games found for 2023-11-07
# Processing games for 2023-11-08...
# Processed game 0022300157 for date 2023-11-08.
# Processed game 0022300158 for date 2023-11-08.
# Processed game 0022300159 for date 2023-11-08.
# Processed game 0022300160 for date 2023-11-08.
# Processed game 0022300161 for date 2023-11-08.
# Processed game 0022300162 for date 2023-11-08.
# Processed game 0022300163 for date 2023-11-08.
# Processed game 0022300164 for date 2023-11-08.
# Processed game 0022300165 for date 2023-11-08.
# Processed game 0022300166 for date 2023-11-08.
# Processed game 0022300167 for date 2023-11-08.
# Processed game 0022300168 for date 2023-11-08.
# Processed game 0022300169 for date 2023-11-08.
# Processed game 0022300170 for date 2023-11-08.
# Processing games for 2023-11-09...
# Processed game 0022300171 for date 2023-11-09.
# Processed game 0022300172 for date 2023-11-09.
# Processing games for 2023-11-10...
# Processed game 0022300008 for date 2023-11-10.
# Processed game 0022300009 for date 2023-11-10.
# Processed game 0022300010 for date 2023-11-10.
# Processed game 0022300011 for date 2023-11-10.
# Processed game 0022300012 for date 2023-11-10.
# Processed game 0022300013 for date 2023-11-10.
# Processed game 0022300014 for date 2023-11-10.
# Processed game 0022300015 for date 2023-11-10.
# Processed game 0022300016 for date 2023-11-10.
# Processing games for 2023-11-11...
# Processed game 0022300173 for date 2023-11-11.
# Processed game 0022300174 for date 2023-11-11.
# Processed game 0022300175 for date 2023-11-11.
# Processed game 0022300176 for date 2023-11-11.
# Processing games for 2023-11-12...
# Processed game 0022300177 for date 2023-11-12.
# Processed game 0022300178 for date 2023-11-12.
# Processed game 0022300179 for date 2023-11-12.
# Processed game 0022300180 for date 2023-11-12.
# Processed game 0022300181 for date 2023-11-12.
# Processed game 0022300182 for date 2023-11-12.
# Processed game 0022300183 for date 2023-11-12.
# Processed game 0022300184 for date 2023-11-12.
# Processed game 0022300185 for date 2023-11-12.
# Processed game 0022300186 for date 2023-11-12.
# Processed game 0022300187 for date 2023-11-12.
# Processing games for 2023-11-13...
# Processed game 0022300188 for date 2023-11-13.
# Processed game 0022300189 for date 2023-11-13.
# Processed game 0022300190 for date 2023-11-13.
# Processed game 0022300191 for date 2023-11-13.
# Processing games for 2023-11-14...
# Processed game 0022300017 for date 2023-11-14.
# Processed game 0022300018 for date 2023-11-14.
# Processed game 0022300019 for date 2023-11-14.
# Processed game 0022300020 for date 2023-11-14.
# Processed game 0022300021 for date 2023-11-14.
# Processed game 0022300022 for date 2023-11-14.
# Processed game 0022300023 for date 2023-11-14.
# Processed game 0022300024 for date 2023-11-14.
# Processed game 0022300025 for date 2023-11-14.
# Processed game 0022300026 for date 2023-11-14.
# Processing games for 2023-11-15...
# Processed game 0022300192 for date 2023-11-15.
# Processed game 0022300193 for date 2023-11-15.
# Processed game 0022300194 for date 2023-11-15.
# Processed game 0022300195 for date 2023-11-15.
# Processed game 0022300196 for date 2023-11-15.
# Processed game 0022300197 for date 2023-11-15.
# Processed game 0022300198 for date 2023-11-15.
# Processed game 0022300199 for date 2023-11-15.
# Processing games for 2023-11-16...
# Processed game 0022300200 for date 2023-11-16.
# Processed game 0022300201 for date 2023-11-16.
# Processing games for 2023-11-17...
# Processed game 0022300027 for date 2023-11-17.
# Processed game 0022300028 for date 2023-11-17.
# Processed game 0022300029 for date 2023-11-17.
# Processed game 0022300030 for date 2023-11-17.
# Processed game 0022300031 for date 2023-11-17.
# Processed game 0022300032 for date 2023-11-17.
# Processed game 0022300033 for date 2023-11-17.
# Processed game 0022300034 for date 2023-11-17.
# Processed game 0022300035 for date 2023-11-17.
# Processed game 0022300036 for date 2023-11-17.
# Processed game 0022300037 for date 2023-11-17.
# Processing games for 2023-11-18...
# Processed game 0022300202 for date 2023-11-18.
# Processed game 0022300203 for date 2023-11-18.
# Processed game 0022300204 for date 2023-11-18.
# Processed game 0022300205 for date 2023-11-18.
# Processed game 0022300206 for date 2023-11-18.
# Processed game 0022300207 for date 2023-11-18.
# Processing games for 2023-11-19...
# Processed game 0022300208 for date 2023-11-19.
# Processed game 0022300211 for date 2023-11-19.
# Processed game 0022300209 for date 2023-11-19.
# Processed game 0022300210 for date 2023-11-19.
# Processed game 0022300212 for date 2023-11-19.
# Processed game 0022300213 for date 2023-11-19.
# Processed game 0022300214 for date 2023-11-19.
# Processed game 0022300215 for date 2023-11-19.
# Processed game 0022300216 for date 2023-11-19.
# Processing games for 2023-11-20...
# Processed game 0022300217 for date 2023-11-20.
# Processed game 0022300218 for date 2023-11-20.
# Processed game 0022300219 for date 2023-11-20.
# Processed game 0022300220 for date 2023-11-20.
# Processed game 0022300221 for date 2023-11-20.
# Processed game 0022300222 for date 2023-11-20.
# Processed game 0022300223 for date 2023-11-20.
# Processed game 0022300224 for date 2023-11-20.
# Processing games for 2023-11-21...
# Processed game 0022300038 for date 2023-11-21.
# Processed game 0022300039 for date 2023-11-21.
# Processed game 0022300040 for date 2023-11-21.
# Processed game 0022300041 for date 2023-11-21.
# Processed game 0022300042 for date 2023-11-21.
# Processing games for 2023-11-22...
# Processed game 0022300225 for date 2023-11-22.
# Processed game 0022300226 for date 2023-11-22.
# Processed game 0022300227 for date 2023-11-22.
# Processed game 0022300228 for date 2023-11-22.
# Processed game 0022300229 for date 2023-11-22.
# Processed game 0022300230 for date 2023-11-22.
# Processed game 0022300231 for date 2023-11-22.
# Processed game 0022300232 for date 2023-11-22.
# Processed game 0022300233 for date 2023-11-22.
# Processed game 0022300234 for date 2023-11-22.
# Processed game 0022300235 for date 2023-11-22.
# Processed game 0022300236 for date 2023-11-22.
# Processed game 0022300237 for date 2023-11-22.
# Processed game 0022300238 for date 2023-11-22.
# Processing games for 2023-11-23...
# No games found for 2023-11-23
# Processing games for 2023-11-24...
# Processed game 0022300043 for date 2023-11-24.
# Processed game 0022300044 for date 2023-11-24.
# Processed game 0022300045 for date 2023-11-24.
# Processed game 0022300046 for date 2023-11-24.
# Processed game 0022300047 for date 2023-11-24.
# Processed game 0022300048 for date 2023-11-24.
# Processed game 0022300049 for date 2023-11-24.
# Processed game 0022300050 for date 2023-11-24.
# Processed game 0022300051 for date 2023-11-24.
# Processed game 0022300052 for date 2023-11-24.
# Processing games for 2023-11-25...
# Processed game 0022300239 for date 2023-11-25.
# Processed game 0022300240 for date 2023-11-25.
# Processed game 0022300241 for date 2023-11-25.
# Processed game 0022300242 for date 2023-11-25.
# Processed game 0022300243 for date 2023-11-25.
# Processed game 0022300244 for date 2023-11-25.
# Processing games for 2023-11-26...
# Processed game 0022300245 for date 2023-11-26.
# Processed game 0022300246 for date 2023-11-26.
# Processed game 0022300247 for date 2023-11-26.
# Processed game 0022300248 for date 2023-11-26.
# Processed game 0022300249 for date 2023-11-26.
# Processed game 0022300250 for date 2023-11-26.
# Processed game 0022300251 for date 2023-11-26.
# Processed game 0022300252 for date 2023-11-26.
# Processing games for 2023-11-27...
# Processed game 0022300253 for date 2023-11-27.
# Processed game 0022300254 for date 2023-11-27.
# Processed game 0022300255 for date 2023-11-27.
# Processed game 0022300256 for date 2023-11-27.
# Processed game 0022300257 for date 2023-11-27.
# Processing games for 2023-11-28...
# Processed game 0022300053 for date 2023-11-28.
# Processed game 0022300054 for date 2023-11-28.
# Processed game 0022300055 for date 2023-11-28.
# Processed game 0022300056 for date 2023-11-28.
# Processed game 0022300057 for date 2023-11-28.
# Processed game 0022300058 for date 2023-11-28.
# Processed game 0022300059 for date 2023-11-28.
# Processed game 0022300060 for date 2023-11-28.
# Processing games for 2023-11-29...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:49:17 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 2s...
# 18:49:44 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:50:17 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:50:51 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 16s...
# 18:51:26 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 18:52:13 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 18:53:16 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 18:54:50 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Max retries exceeded with url: /stats/scoreboardv2?DayOffset=0&GameDate=2023-11-29&LeagueID=00 (Caused by NameResolutionError("<urllib3.connection.HTTPSConnection object at 0x000001801D872C30>: Failed to resolve 'stats.nba.com' ([Errno 11001] getaddrinfo failed)")). Retrying in 256s...
# 18:59:36 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 19:04:23 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1024s...
# 19:13:17 03/27/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 2048s...
# 19:30:43 03/27/25 Eastern Daylight Time
# Processed game 0022300258 for date 2023-11-29.
# Processed game 0022300259 for date 2023-11-29.
# Processed game 0022300260 for date 2023-11-29.
# Processed game 0022300261 for date 2023-11-29.
# Processed game 0022300262 for date 2023-11-29.
# Processed game 0022300263 for date 2023-11-29.
# Processed game 0022300264 for date 2023-11-29.
# Processing games for 2023-11-30...
# Processed game 0022300265 for date 2023-11-30.
# Processed game 0022300266 for date 2023-11-30.
# Processed game 0022300267 for date 2023-11-30.
# Processed game 0022300268 for date 2023-11-30.
# Processed game 0022300269 for date 2023-11-30.
# Processed game 0022300270 for date 2023-11-30.
# Processed game 0022300271 for date 2023-11-30.
# Processed game 0022300272 for date 2023-11-30.
# Processed game 0022300273 for date 2023-11-30.
# Processing games for 2023-12-01...
# Processed game 0022300274 for date 2023-12-01.
# Processed game 0022300275 for date 2023-12-01.
# Processed game 0022300276 for date 2023-12-01.
# Processed game 0022300277 for date 2023-12-01.
# Processed game 0022300278 for date 2023-12-01.
# Processed game 0022300279 for date 2023-12-01.
# Processing games for 2023-12-02...
# Processed game 0022300280 for date 2023-12-02.
# Processed game 0022300281 for date 2023-12-02.
# Processed game 0022300282 for date 2023-12-02.
# Processed game 0022300283 for date 2023-12-02.
# Processed game 0022300284 for date 2023-12-02.
# Processed game 0022300285 for date 2023-12-02.
# Processed game 0022300286 for date 2023-12-02.
# Processed game 0022300287 for date 2023-12-02.
# Processed game 0022300288 for date 2023-12-02.
# Processed game 0022300289 for date 2023-12-02.
# Processed game 0022300290 for date 2023-12-02.
# Processed game 0022300291 for date 2023-12-02.
# Processing games for 2023-12-03...
# No games found for 2023-12-03
# Processing games for 2023-12-04...
# Processed game 0022301202 for date 2023-12-04.
# Processed game 0022301204 for date 2023-12-04.
# Processing games for 2023-12-05...
# Processed game 0022301201 for date 2023-12-05.
# Processed game 0022301203 for date 2023-12-05.
# Processing games for 2023-12-06...
# Processed game 0022301205 for date 2023-12-06.
# Processed game 0022301206 for date 2023-12-06.
# Processed game 0022301208 for date 2023-12-06.
# Processed game 0022301207 for date 2023-12-06.
# Processed game 0022301209 for date 2023-12-06.
# Processed game 0022301210 for date 2023-12-06.
# Processed game 0022301211 for date 2023-12-06.
# Processed game 0022301212 for date 2023-12-06.
# Processed game 0022301213 for date 2023-12-06.
# Processed game 0022301214 for date 2023-12-06.
# Processed game 0022301215 for date 2023-12-06.
# Processing games for 2023-12-07...
# Processed game 0022301229 for date 2023-12-07.
# Processed game 0022301230 for date 2023-12-07.
# Processing games for 2023-12-08...
# Processed game 0022301216 for date 2023-12-08.
# Processed game 0022301217 for date 2023-12-08.
# Processed game 0022301218 for date 2023-12-08.
# Processed game 0022301219 for date 2023-12-08.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 20:08:57 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 20:09:29 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 20:10:01 03/27/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 20:10:36 03/27/25 Eastern Daylight Time
# ...
# Processed game 0022300931 for date 2024-03-10.
# Processed game 0022300932 for date 2024-03-10.
# Processing games for 2024-03-11...
# Processed game 0022300933 for date 2024-03-11.
# Processed game 0022300934 for date 2024-03-11.
# Processed game 0022300935 for date 2024-03-11.
# Processed game 0022300936 for date 2024-03-11.
# Processed game 0022300937 for date 2024-03-11.
# Processed game 0022300938 for date 2024-03-11.
# Processing games for 2024-03-12...
# Processed game 0022300939 for date 2024-03-12.
# Processed game 0022300940 for date 2024-03-12.
# Processed game 0022300941 for date 2024-03-12.
# Processed game 0022300942 for date 2024-03-12.
# Processed game 0022300943 for date 2024-03-12.
# Processed game 0022300944 for date 2024-03-12.
# Processed game 0022300945 for date 2024-03-12.
# Processing games for 2024-03-13...
# Processed game 0022300946 for date 2024-03-13.
# Processed game 0022300947 for date 2024-03-13.
# Processed game 0022300948 for date 2024-03-13.
# Processed game 0022300949 for date 2024-03-13.
# Processed game 0022300950 for date 2024-03-13.
# Processed game 0022300951 for date 2024-03-13.
# Processed game 0022300952 for date 2024-03-13.
# Processed game 0022300953 for date 2024-03-13.
# Processed game 0022300954 for date 2024-03-13.
# Processing games for 2024-03-14...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 01:01:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 01:01:49 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 01:02:21 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 01:02:55 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 01:03:33 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 01:04:20 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 01:05:22 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 01:06:56 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 256s...
# 01:09:31 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 01:14:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 01:23:20 03/28/25 Eastern Daylight Time
# Processed game 0022300955 for date 2024-03-14.
# Processed game 0022300956 for date 2024-03-14.
# Processed game 0022300957 for date 2024-03-14.
# Processed game 0022300958 for date 2024-03-14.
# Processed game 0022300959 for date 2024-03-14.
# Processed game 0022300960 for date 2024-03-14.
# Processing games for 2024-03-15...
# Processed game 0022300961 for date 2024-03-15.
# Processed game 0022300962 for date 2024-03-15.
# Processed game 0022300963 for date 2024-03-15.
# Processed game 0022300964 for date 2024-03-15.
# Processed game 0022300965 for date 2024-03-15.
# Processed game 0022300966 for date 2024-03-15.
# Processing games for 2024-03-16...
# Processed game 0022300967 for date 2024-03-16.
# Processed game 0022300968 for date 2024-03-16.
# Processed game 0022300969 for date 2024-03-16.
# Processed game 0022300970 for date 2024-03-16.
# Processed game 0022300971 for date 2024-03-16.
# Processed game 0022300972 for date 2024-03-16.
# Processed game 0022300973 for date 2024-03-16.
# Processed game 0022300974 for date 2024-03-16.
# Processed game 0022300975 for date 2024-03-16.
# Processing games for 2024-03-17...
# Processed game 0022300976 for date 2024-03-17.
# Processed game 0022300977 for date 2024-03-17.
# Processed game 0022300978 for date 2024-03-17.
# Processed game 0022300979 for date 2024-03-17.
# Processed game 0022300980 for date 2024-03-17.
# Processed game 0022300981 for date 2024-03-17.
# Processed game 0022300982 for date 2024-03-17.
# Processing games for 2024-03-18...
# Processed game 0022300983 for date 2024-03-18.
# Processed game 0022300984 for date 2024-03-18.
# Processed game 0022300985 for date 2024-03-18.
# Processed game 0022300986 for date 2024-03-18.
# Processed game 0022300987 for date 2024-03-18.
# Processed game 0022300988 for date 2024-03-18.
# Processed game 0022300989 for date 2024-03-18.
# Processed game 0022300990 for date 2024-03-18.
# Processing games for 2024-03-19...
# Processed game 0022300991 for date 2024-03-19.
# Processed game 0022300992 for date 2024-03-19.
# Processed game 0022300993 for date 2024-03-19.
# Processed game 0022300994 for date 2024-03-19.
# Processed game 0022300995 for date 2024-03-19.
# Processing games for 2024-03-20...
# Processed game 0022300996 for date 2024-03-20.
# Processed game 0022300997 for date 2024-03-20.
# Processed game 0022300998 for date 2024-03-20.
# Processed game 0022300999 for date 2024-03-20.
# Processed game 0022301000 for date 2024-03-20.
# Processed game 0022301001 for date 2024-03-20.
# Processed game 0022301002 for date 2024-03-20.
# Processed game 0022301003 for date 2024-03-20.
# Processing games for 2024-03-21...
# Processed game 0022301004 for date 2024-03-21.
# Processed game 0022301005 for date 2024-03-21.
# Processed game 0022301006 for date 2024-03-21.
# Processed game 0022301007 for date 2024-03-21.
# Processed game 0022301008 for date 2024-03-21.
# Processed game 0022301009 for date 2024-03-21.
# Processed game 0022301010 for date 2024-03-21.
# Processing games for 2024-03-22...
# Processed game 0022301011 for date 2024-03-22.
# Processed game 0022301012 for date 2024-03-22.
# Processed game 0022301013 for date 2024-03-22.
# Processed game 0022301014 for date 2024-03-22.
# Processed game 0022301015 for date 2024-03-22.
# Processed game 0022301016 for date 2024-03-22.
# Processed game 0022301017 for date 2024-03-22.
# Processed game 0022301018 for date 2024-03-22.
# Processing games for 2024-03-23...
# Processed game 0022301019 for date 2024-03-23.
# Processed game 0022301020 for date 2024-03-23.
# Processed game 0022301021 for date 2024-03-23.
# Processed game 0022301022 for date 2024-03-23.
# Processed game 0022301023 for date 2024-03-23.
# Processed game 0022301024 for date 2024-03-23.
# Processed game 0022301025 for date 2024-03-23.
# Processed game 0022301026 for date 2024-03-23.
# Processing games for 2024-03-24...
# Processed game 0022301027 for date 2024-03-24.
# Processed game 0022301028 for date 2024-03-24.
# Processed game 0022301029 for date 2024-03-24.
# Processed game 0022301030 for date 2024-03-24.
# Processed game 0022301031 for date 2024-03-24.
# Processed game 0022301032 for date 2024-03-24.
# Processing games for 2024-03-25...
# Processed game 0022301033 for date 2024-03-25.
# Processed game 0022301034 for date 2024-03-25.
# Processed game 0022301035 for date 2024-03-25.
# Processed game 0022301036 for date 2024-03-25.
# Processed game 0022301037 for date 2024-03-25.
# Processed game 0022301038 for date 2024-03-25.
# Processed game 0022301039 for date 2024-03-25.
# Processed game 0022301040 for date 2024-03-25.
# Processed game 0022301041 for date 2024-03-25.
# Processed game 0022301042 for date 2024-03-25.
# Processed game 0022301043 for date 2024-03-25.
# Processing games for 2024-03-26...
# Processed game 0022301044 for date 2024-03-26.
# Processed game 0022301045 for date 2024-03-26.
# Processed game 0022301046 for date 2024-03-26.
# Processed game 0022301047 for date 2024-03-26.
# Processing games for 2024-03-27...
# Processed game 0022301048 for date 2024-03-27.
# Processed game 0022301049 for date 2024-03-27.
# Processed game 0022301050 for date 2024-03-27.
# Processed game 0022301051 for date 2024-03-27.
# Processed game 0022301052 for date 2024-03-27.
# Processed game 0022301053 for date 2024-03-27.
# Processed game 0022301054 for date 2024-03-27.
# Processed game 0022301055 for date 2024-03-27.
# Processed game 0022301056 for date 2024-03-27.
# Processed game 0022301057 for date 2024-03-27.
# Processed game 0022301058 for date 2024-03-27.
# Processed game 0022301059 for date 2024-03-27.
# Processing games for 2024-03-28...
# Processed game 0022301060 for date 2024-03-28.
# Processed game 0022301061 for date 2024-03-28.
# Processing games for 2024-03-29...
# Processed game 0022301062 for date 2024-03-29.
# Processed game 0022301063 for date 2024-03-29.
# Processed game 0022301064 for date 2024-03-29.
# Processed game 0022301065 for date 2024-03-29.
# Processed game 0022301066 for date 2024-03-29.
# Processed game 0022301067 for date 2024-03-29.
# Processed game 0022301068 for date 2024-03-29.
# Processed game 0022301069 for date 2024-03-29.
# Processed game 0022301070 for date 2024-03-29.
# Processed game 0022301071 for date 2024-03-29.
# Processed game 0022301072 for date 2024-03-29.
# Processed game 0022301073 for date 2024-03-29.
# Processing games for 2024-03-30...
# Processed game 0022301074 for date 2024-03-30.
# Processed game 0022301075 for date 2024-03-30.
# Processed game 0022301076 for date 2024-03-30.
# Processing games for 2024-03-31...
# Processed game 0022301077 for date 2024-03-31.
# Processed game 0022301078 for date 2024-03-31.
# Processed game 0022301079 for date 2024-03-31.
# Processed game 0022301080 for date 2024-03-31.
# Processed game 0022301081 for date 2024-03-31.
# Processed game 0022301082 for date 2024-03-31.
# Processed game 0022301083 for date 2024-03-31.
# Processed game 0022301084 for date 2024-03-31.
# Processed game 0022301085 for date 2024-03-31.
# Processed game 0022301086 for date 2024-03-31.
# Processing games for 2024-04-01...
# Processed game 0022301087 for date 2024-04-01.
# Processed game 0022301088 for date 2024-04-01.
# Processed game 0022301089 for date 2024-04-01.
# Processed game 0022301090 for date 2024-04-01.
# Processed game 0022301091 for date 2024-04-01.
# Processed game 0022301092 for date 2024-04-01.
# Processing games for 2024-04-02...
# Processed game 0022301094 for date 2024-04-02.
# Processed game 0022301095 for date 2024-04-02.
# Processed game 0022301093 for date 2024-04-02.
# Processed game 0022301096 for date 2024-04-02.
# Processed game 0022301098 for date 2024-04-02.
# Processed game 0022301099 for date 2024-04-02.
# Processed game 0022301100 for date 2024-04-02.
# Processed game 0022300589 for date 2024-04-02.
# Processed game 0022301101 for date 2024-04-02.
# Processing games for 2024-04-03...
# Processed game 0022301102 for date 2024-04-03.
# Processed game 0022301103 for date 2024-04-03.
# Processed game 0022301104 for date 2024-04-03.
# Processed game 0022301105 for date 2024-04-03.
# Processed game 0022301106 for date 2024-04-03.
# Processed game 0022301107 for date 2024-04-03.
# Processed game 0022301108 for date 2024-04-03.
# Processed game 0022301109 for date 2024-04-03.
# Processed game 0022301110 for date 2024-04-03.
# Processing games for 2024-04-04...
# Processed game 0022301111 for date 2024-04-04.
# Processed game 0022301112 for date 2024-04-04.
# Processed game 0022301124 for date 2024-04-04.
# Processed game 0022301113 for date 2024-04-04.
# Processed game 0022301114 for date 2024-04-04.
# Processing games for 2024-04-05...
# Processed game 0022301115 for date 2024-04-05.
# Processed game 0022301116 for date 2024-04-05.
# Processed game 0022301117 for date 2024-04-05.
# Processed game 0022301118 for date 2024-04-05.
# Processed game 0022301119 for date 2024-04-05.
# Processed game 0022301120 for date 2024-04-05.
# Processed game 0022301121 for date 2024-04-05.
# Processed game 0022301122 for date 2024-04-05.
# Processed game 0022301123 for date 2024-04-05.
# Processed game 0022301097 for date 2024-04-05.
# Processed game 0022301125 for date 2024-04-05.
# Processed game 0022301126 for date 2024-04-05.
# Processing games for 2024-04-06...
# Processed game 0022301127 for date 2024-04-06.
# Processed game 0022301128 for date 2024-04-06.
# Processed game 0022301129 for date 2024-04-06.
# Processed game 0022301130 for date 2024-04-06.
# Processing games for 2024-04-07...
# Processed game 0022301131 for date 2024-04-07.
# Processed game 0022301132 for date 2024-04-07.
# Processed game 0022301133 for date 2024-04-07.
# Processed game 0022301134 for date 2024-04-07.
# Processed game 0022301199 for date 2024-04-14.
# Processed game 0022301200 for date 2024-04-14.
# 1513 games processed
# 1513 unique games with player stats

# %%
import time
import random
from datetime import date, timedelta
import pandas as pd

# Initialize DataFrames
teams_df = pd.DataFrame(columns=['team_id', 'season_year', 'team_location', 'team_name', 'team_abbreviation'])
players_df = pd.DataFrame(columns=['player_id', 'player_first_name', 'player_last_name'])
games_df = pd.DataFrame(columns=['game_id', 'season_year', 'game_date', 'home_team_id', 'away_team_id'])
player_game_stats_df = pd.DataFrame(columns=['game_id', 'player_id', 'team_id', 'player_game_stats'])

start_date = date(2024, 4, 15)
end_date = date(2025, 3, 29)

current_date = start_date
current_highest_season = ""

# Function to simulate an API request with retries and exponential backoff
def fetch_with_retry(func, *args, **kwargs):
    retries = 20  # Number of retries
    delay = 1  # Initial delay time in seconds
    for attempt in range(retries):
        try:
            # Call the original function with passed arguments and keyword arguments
            return func(*args, **kwargs)
        except Exception as e:
            if attempt < retries - 1:
                print(f"Error inside retry fn: {e}. Retrying in {delay}s...")
                #print the current time
                print(time.strftime('%X %x %Z'))
                time.sleep(delay)
                delay *= 2  # Exponential backoff
            else:
                print(f"Failed after {retries} attempts: {e}")
                return None

# Request limit settings
delay_between_requests = 1  # Start with a 60-second delay (1 request per minute)
max_delay = 360  # Maximum delay of 6 minutes (to prevent overwhelming the server)

while current_date <= end_date:
    print(f"Processing games for {current_date}...")
    
    # Add a random sleep time to avoid hitting rate limits
    time.sleep(random.uniform(1.0, 2.0))
    
    # Fetch the games data with retry and exponential backoff
    games = fetch_with_retry(endpoints.scoreboardv2.ScoreboardV2, game_date=current_date)
    
    if games is None:
        # If the fetch failed after retries, skip this date
        start_date += timedelta(days=1)
        print(f"Failed to fetch games for {current_date}. Skipping.")
        continue
    
    try:
        games_data = games.get_data_frames()[0]
        game_ids = games_data['GAME_ID']

        if len(game_ids) > 0:
            current_highest_season = get_season(game_ids[0])  # Assuming get_season is defined somewhere
        else:
            print(f"No games found for {current_date}")
    except Exception as e:
        print(f"Error processing games for {current_date}: {e}. Skipping")
        start_date += timedelta(days=1)
        continue
    
    # Loop through all the game IDs and fetch the box score data
    for game_id in game_ids:
        # Get all stats using BoxScoreTraditionalV2 with retry and exponential backoff
        while True:
            boxscore = fetch_with_retry(endpoints.boxscoretraditionalv2.BoxScoreTraditionalV2, game_id=game_id)
            
            if boxscore is None:
                print(f"Error fetching stats for game {game_id} -- boxscore is None. Tryinhg again")
                continue

            try:
                player_stats = boxscore.get_data_frames()[0]
                team_stats = boxscore.get_data_frames()[1]
                
                teams_df = fill_teams_df(game_id, team_stats, teams_df)
                players_df = fill_players_df(player_stats, players_df)
                games_df = fill_games_df(game_id, current_date, games_df)
                player_game_stats_df = get_player_game_stats(game_id, player_stats, player_game_stats_df)

                teams_df.to_csv(f'teams-old-3.csv', index=False)
                players_df.to_csv(f'players-old-3.csv', index=False)
                games_df.to_csv(f'games-old-3.csv', index=False)
                player_game_stats_df.to_csv(f'player_game_stats-old-3.csv', index=False)
                print(f"Processed game {game_id} for date {current_date}.")

                break


            except Exception as e:
                print(f"Error processing stats for game {game_id}: {e}. Trying Again")
                continue

    # After processing all games, move to the next 1 days
    current_date += timedelta(days=1)

    # Implement request throttling based on rate limits
    time.sleep(delay_between_requests + random.uniform(0, 1))  # Adding a bit of randomness to avoid clustered requests

    # Apply exponential backoff: increase delay after each request to manage rate limits
    delay_between_requests = min(delay_between_requests, max_delay)

# print(teams_df)
# print('\n')
# print(players_df)
# print('\n')
# print(games_df)
# print('\n')
# print(player_game_stats_df)

print(len(games_df.game_id.unique()), "games processed")
print(len(player_game_stats_df.game_id.unique()), "unique games with player stats")
# Out:
# Processing games for 2024-04-15...
# No games found for 2024-04-15
# Processing games for 2024-04-16...
# Processed game 0052300121 for date 2024-04-16.
# Processed game 0052300131 for date 2024-04-16.
# Processing games for 2024-04-17...
# Processed game 0052300101 for date 2024-04-17.
# Processed game 0052300111 for date 2024-04-17.
# Processing games for 2024-04-18...
# No games found for 2024-04-18
# Processing games for 2024-04-19...
# Processed game 0052300201 for date 2024-04-19.
# Processed game 0052300211 for date 2024-04-19.
# Processing games for 2024-04-20...
# Processed game 0042300131 for date 2024-04-20.
# Processed game 0042300161 for date 2024-04-20.
# Processed game 0042300111 for date 2024-04-20.
# Processed game 0042300151 for date 2024-04-20.
# Processing games for 2024-04-21...
# Processed game 0042300101 for date 2024-04-21.
# Processed game 0042300171 for date 2024-04-21.
# Processed game 0042300121 for date 2024-04-21.
# Processed game 0042300141 for date 2024-04-21.
# Processing games for 2024-04-22...
# Processed game 0042300132 for date 2024-04-22.
# Processed game 0042300112 for date 2024-04-22.
# Processed game 0042300152 for date 2024-04-22.
# Processing games for 2024-04-23...
# Processed game 0042300162 for date 2024-04-23.
# Processed game 0042300122 for date 2024-04-23.
# Processed game 0042300172 for date 2024-04-23.
# Processing games for 2024-04-24...
# Processed game 0042300102 for date 2024-04-24.
# Processed game 0042300142 for date 2024-04-24.
# Processing games for 2024-04-25...
# Processed game 0042300133 for date 2024-04-25.
# Processed game 0042300113 for date 2024-04-25.
# Processed game 0042300153 for date 2024-04-25.
# Processing games for 2024-04-26...
# Processed game 0042300123 for date 2024-04-26.
# Processed game 0042300173 for date 2024-04-26.
# Processed game 0042300163 for date 2024-04-26.
# Processing games for 2024-04-27...
# Processed game 0042300134 for date 2024-04-27.
# Processed game 0042300143 for date 2024-04-27.
# Processed game 0042300103 for date 2024-04-27.
# Processed game 0042300154 for date 2024-04-27.
# Processing games for 2024-04-28...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 01:56:16 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 01:56:47 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 01:57:19 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 01:57:53 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 01:58:32 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 01:59:18 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 02:00:20 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 02:01:54 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 02:04:33 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 02:09:19 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 02:18:21 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 
# Processing games for 2024-10-13...
# Processed game 0012400039 for date 2024-10-13.
# Processed game 0012400040 for date 2024-10-13.
# Processed game 0012400041 for date 2024-10-13.
# Processed game 0012400042 for date 2024-10-13.
# Processed game 0012400043 for date 2024-10-13.
# Processed game 0012400044 for date 2024-10-13.
# Processing games for 2024-10-14...
# Processed game 0012400045 for date 2024-10-14.
# Processed game 0012400046 for date 2024-10-14.
# Processed game 0012400047 for date 2024-10-14.
# Processed game 0012400048 for date 2024-10-14.
# Processed game 0012400049 for date 2024-10-14.
# Processing games for 2024-10-15...
# Processed game 0012400050 for date 2024-10-15.
# Processed game 0012400051 for date 2024-10-15.
# Processed game 0012400052 for date 2024-10-15.
# Processed game 0012400053 for date 2024-10-15.
# Processed game 0012400054 for date 2024-10-15.
# Processed game 0012400055 for date 2024-10-15.
# Processed game 0012400056 for date 2024-10-15.
# Processing games for 2024-10-16...
# Processed game 0012400057 for date 2024-10-16.
# Processed game 0012400058 for date 2024-10-16.
# Processed game 0012400025 for date 2024-10-16.
# Processed game 0012400059 for date 2024-10-16.
# Processed game 0012400060 for date 2024-10-16.
# Processing games for 2024-10-17...
# Processed game 0012400061 for date 2024-10-17.
# Processed game 0012400062 for date 2024-10-17.
# Processed game 0012400063 for date 2024-10-17.
# Processed game 0012400064 for date 2024-10-17.
# Processed game 0012400072 for date 2024-10-17.
# Processed game 0012400065 for date 2024-10-17.
# Processed game 0012400066 for date 2024-10-17.
# Processing games for 2024-10-18...
# Processed game 0012400067 for date 2024-10-18.
# Processed game 0012400068 for date 2024-10-18.
# Processed game 0012400069 for date 2024-10-18.
# Processed game 0012400070 for date 2024-10-18.
# Processed game 0012400071 for date 2024-10-18.
# Processed game 0012400073 for date 2024-10-18.
# Processed game 0012400074 for date 2024-10-18.
# Processing games for 2024-10-19...
# No games found for 2024-10-19
# Processing games for 2024-10-20...
# No games found for 2024-10-20
# Processing games for 2024-10-21...
# No games found for 2024-10-21
# Processing games for 2024-10-22...
# Processed game 0022400061 for date 2024-10-22.
# Processed game 0022400062 for date 2024-10-22.
# Processing games for 2024-10-23...
# Processed game 0022400063 for date 2024-10-23.
# Processed game 0022400064 for date 2024-10-23.
# Processed game 0022400065 for date 2024-10-23.
# Processed game 0022400066 for date 2024-10-23.
# Processed game 0022400067 for date 2024-10-23.
# Processed game 0022400068 for date 2024-10-23.
# Processed game 0022400069 for date 2024-10-23.
# Error processing stats for game 0022400070: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Trying Again
# Processed game 0022400070 for date 2024-10-23.
# Processed game 0022400071 for date 2024-10-23.
# Processed game 0022400072 for date 2024-10-23.
# Processing games for 2024-10-24...
# Processed game 0022400073 for date 2024-10-24.
# Processed game 0022400074 for date 2024-10-24.
# Processed game 0022400075 for date 2024-10-24.
# Processed game 0022400076 for date 2024-10-24.
# Processing games for 2024-10-25...
# Processed game 0022400077 for date 2024-10-25.
# Processed game 0022400078 for date 2024-10-25.
# Processed game 0022400079 for date 2024-10-25.
# Processed game 0022400080 for date 2024-10-25.
# Processed game 0022400081 for date 2024-10-25.
# Processed game 0022400082 for date 2024-10-25.
# Processed game 0022400083 for date 2024-10-25.
# Processed game 0022400084 for date 2024-10-25.
# Processed game 0022400085 for date 2024-10-25.
# Processed game 0022400086 for date 2024-10-25.
# Processing games for 2024-10-26...
# Processed game 0022400087 for date 2024-10-26.
# Processed game 0022400088 for date 2024-10-26.
# Processed game 0022400089 for date 2024-10-26.
# Processed game 0022400090 for date 2024-10-26.
# Processed game 0022400091 for date 2024-10-26.
# Processed game 0022400092 for date 2024-10-26.
# Processed game 0022400093 for date 2024-10-26.
# Error processing stats for game 0022400094: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Trying Again
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 04:10:30 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 04:11:01 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 04:11:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 04:12:08 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 04:12:46 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 04:13:33 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 04:14:35 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 04:16:09 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 04:18:47 03/28/25 Eastern Daylight Time
# Processed game 0022400094 for date 2024-10-26.
# Processed game 0022400095 for date 2024-10-26.
# Processed game 0022400096 for date 2024-10-26.
# Processing games for 2024-10-27...
# Processed game 0022400097 for date 2024-10-27.
# Processed game 0022400098 for date 2024-10-27.
# Processed game 0022400099 for date 2024-10-27.
# Processed game 0022400100 for date 2024-10-27.
# Processed game 0022400101 for date 2024-10-27.
# Processing games for 2024-10-28...
# Processed game 0022400102 for date 2024-10-28.
# Processed game 0022400103 for date 2024-10-28.
# Processed game 0022400104 for date 2024-10-28.
# Processed game 0022400105 for date 2024-10-28.
# Processed game 0022400106 for date 2024-10-28.
# Processed game 0022400107 for date 2024-10-28.
# Processed game 0022400108 for date 2024-10-28.
# Error processing stats for game 0022400109: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Trying Again
# Processed game 0022400109 for date 2024-10-28.
# Processed game 0022400110 for date 2024-10-28.
# Processed game 0022400111 for date 2024-10-28.
# Processed game 0022400112 for date 2024-10-28.
# Processing games for 2024-10-29...
# Processed game 0022400113 for date 2024-10-29.
# Processed game 0022400114 for date 2024-10-29.
# Processed game 0022400115 for date 2024-10-29.
# Processed game 0022400116 for date 2024-10-29.
# Processing games for 2024-10-30...
# Processed game 0022400117 for date 2024-10-30.
# Processed game 0022400118 for date 2024-10-30.
# Processed game 0022400119 for date 2024-10-30.
# Processed game 0022400120 for date 2024-10-30.
# Processed game 0022400121 for date 2024-10-30.
# Processed game 0022400122 for date 2024-10-30.
# Processed game 0022400123 for date 2024-10-30.
# Processed game 0022400124 for date 2024-10-30.
# Processed game 0022400125 for date 2024-10-30.
# Processed game 0022400126 for date 2024-10-30.
# Processed game 0022400127 for date 2024-10-30.
# Processing games for 2024-10-31...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 04:24:37 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 04:25:09 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 04:25:41 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 04:26:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 04:26:53 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 04:27:40 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 04:28:42 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 04:30:16 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 04:32:54 03/28/25 Eastern Daylight Time
# Processed game 0022400128 for date 2024-10-31.
# Processed game 0022400129 for date 2024-10-31.
# Processed game 0022400130 for date 2024-10-31.
# Processed game 0022400131 for date 2024-10-31.
# Processing games for 2024-11-01...
# Processed game 0022400132 for date 2024-11-01.
# Processed game 0022400133 for date 2024-11-01.
# Processed game 0022400134 for date 2024-11-01.
# Processed game 0022400135 for date 2024-11-01.
# Processed game 0022400136 for date 2024-11-01.
# Processed game 0022400137 for date 2024-11-01.
# Processed game 0022400138 for date 2024-11-01.
# Error processing stats for game 0022400139: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Trying Again
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 04:38:21 03/28/25 Eastern Daylight Time
# Processed game 0022400139 for date 2024-11-01.
# Processed game 0022400140 for date 2024-11-01.
# Processing games for 2024-11-02...
# Processed game 0022400141 for date 2024-11-02.
# Processed game 0022400142 for date 2024-11-02.
# Processed game 0022400143 for date 2024-11-02.
# Processed game 0022400144 for date 2024-11-02.
# Processed game 0022400145 for date 2024-11-02.
# Processed game 0022400146 for date 2024-11-02.
# Processed game 0022400147 for date 2024-11-02.
# Processed game 0022400148 for date 2024-11-02.
# Processed game 0022400149 for date 2024-11-02.
# Processed game 0022400150 for date 2024-11-02.
# Processing games for 2024-11-03...
# Processed game 0022400151 for date 2024-11-03.
# Processed game 0022400152 for date 2024-11-03.
# Processed game 0022400153 for date 2024-11-03.
# Processing games for 2024-11-04...
# Processed game 0022400154 for date 2024-11-04.
# Processed game 0022400155 for date 2024-11-04.
# Processed game 0022400156 for date 2024-11-04.
# Processed game 0022400157 for date 2024-11-04.
# Processed game 0022400158 for date 2024-11-04.
# Processed game 0022400159 for date 2024-11-04.
# Processed game 0022400160 for date 2024-11-04.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 04:39:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 04:39:46 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 04:40:18 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 04:40:52 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 04:41:31 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 04:42:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 04:43:19 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 04:44:54 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 04:47:32 03/28/25 Eastern Daylight Time
# Processed game 0022400161 for date 2024-11-04.
# Processed game 0022400162 for date 2024-11-04.
# Processed game 0022400163 for date 2024-11-04.
# Processed game 0022400164 for date 2024-11-04.
# Processed game 0022400165 for date 2024-11-04.
# Processed game 0022400166 for date 2024-11-04.
# Processed game 0022400167 for date 2024-11-04.
# Error processing stats for game 0022400168: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Trying Again
# Processed game 0022400168 for date 2024-11-04.
# Processing games for 2024-11-05...
# No games found for 2024-11-05
# Processing games for 2024-11-06...
# Processed game 0022400169 for date 2024-11-06.
# Processed game 0022400170 for date 2024-11-06.
# Processed game 0022400171 for date 2024-11-06.
# Processed game 0022400172 for date 2024-11-06.
# Processed game 0022400173 for date 2024-11-06.
# Processed game 0022400174 for date 2024-11-06.
# Processed game 0022400175 for date 2024-11-06.
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 04:52:56 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 04:53:27 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 04:54:00 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 04:54:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 04:55:12 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 04:55:58 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 04:57:01 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 04:58:35 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 05:01:13 03/28/25 Eastern Daylight Time
# Processed game 0022400176 for date 2024-11-06.
# Processed game 0022400177 for date 2024-11-06.
# Processed game 0022400178 for date 2024-11-06.
# Processed game 0022400179 for date 2024-11-06.
# Processed game 0022400180 for date 2024-11-06.
# Processing games for 2024-11-07...
# Processed game 0022400181 for date 2024-11-07.
# Processed game 0022400182 for date 2024-11-07.
# Processed game 0022400183 for date 2024-11-07.
# Processing games for 2024-11-08...
# Processed game 0022400184 for date 2024-11-08.
# Processed game 0022400185 for date 2024-11-08.
# Processed game 0022400186 for date 2024-11-08.
# Processed game 0022400187 for date 2024-11-08.
# Processed game 0022400188 for date 2024-11-08.
# Processed game 0022400189 for date 2024-11-08.
# Processed game 0022400190 for date 2024-11-08.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:06:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 05:06:46 03/28/25 Eastern Daylight Time
# Processed game 0022400191 for date 2024-11-08.
# Processed game 0022400192 for date 2024-11-08.
# Processed game 0022400193 for date 2024-11-08.
# Processed game 0022400194 for date 2024-11-08.
# Processed game 0022400195 for date 2024-11-08.
# Processed game 0022400196 for date 2024-11-08.
# Processing games for 2024-11-09...
# Processed game 0022400197 for date 2024-11-09.
# Processed game 0022400198 for date 2024-11-09.
# Processed game 0022400199 for date 2024-11-09.
# Processed game 0022400200 for date 2024-11-09.
# Processing games for 2024-11-10...
# Processed game 0022400201 for date 2024-11-10.
# Processed game 0022400202 for date 2024-11-10.
# Processed game 0022400203 for date 2024-11-10.
# Processed game 0022400204 for date 2024-11-10.
# Processed game 0022400205 for date 2024-11-10.
# Processed game 0022400206 for date 2024-11-10.
# Processed game 0022400207 for date 2024-11-10.
# Processed game 0022400208 for date 2024-11-10.
# Processed game 0022400209 for date 2024-11-10.
# Processed game 0022400210 for date 2024-11-10.
# Processed game 0022400211 for date 2024-11-10.
# Processing games for 2024-11-11...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:07:38 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 05:08:09 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 4s...
# 05:08:33 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 05:09:07 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 05:09:46 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 05:10:32 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 05:11:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 05:13:08 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 05:15:47 03/28/25 Eastern Daylight Time
# Processed game 0022400212 for date 2024-11-11.
# Processed game 0022400213 for date 2024-11-11.
# Processed game 0022400214 for date 2024-11-11.
# Processed game 0022400215 for date 2024-11-11.
# Processed game 0022400216 for date 2024-11-11.
# Processing games for 2024-11-12...
# Processed game 0022400001 for date 2024-11-12.
# Processed game 0022400002 for date 2024-11-12.
# Processed game 0022400003 for date 2024-11-12.
# Processed game 0022400004 for date 2024-11-12.
# Processed game 0022400005 for date 2024-11-12.
# Processed game 0022400006 for date 2024-11-12.
# Processed game 0022400007 for date 2024-11-12.
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 05:20:38 03/28/25 Eastern Daylight Time
# Processed game 0022400008 for date 2024-11-12.
# Processing games for 2024-11-13...
# Processed game 0022400217 for date 2024-11-13.
# Processed game 0022400218 for date 2024-11-13.
# Processed game 0022400219 for date 2024-11-13.
# Processed game 0022400220 for date 2024-11-13.
# Processed game 0022400221 for date 2024-11-13.
# Processed game 0022400222 for date 2024-11-13.
# Processed game 0022400223 for date 2024-11-13.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:21:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 05:21:47 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 05:22:19 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 05:22:53 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 05:23:31 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 05:24:18 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 05:25:20 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 05:26:54 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 05:29:32 03/28/25 Eastern Daylight Time
# Processed game 0022400224 for date 2024-11-13.
# Processed game 0022400225 for date 2024-11-13.
# Processed game 0022400226 for date 2024-11-13.
# Processed game 0022400227 for date 2024-11-13.
# Processing games for 2024-11-14...
# Processed game 0022400228 for date 2024-11-14.
# Processing games for 2024-11-15...
# Processed game 0022400009 for date 2024-11-15.
# Processed game 0022400010 for date 2024-11-15.
# Processed game 0022400011 for date 2024-11-15.
# Processed game 0022400012 for date 2024-11-15.
# Processed game 0022400013 for date 2024-11-15.
# Processed game 0022400014 for date 2024-11-15.
# Processed game 0022400015 for date 2024-11-15.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:34:30 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 05:35:01 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 05:35:33 03/28/25 Eastern Daylight Time
# Processed game 0022400016 for date 2024-11-15.
# Processed game 0022400017 for date 2024-11-15.
# Processed game 0022400018 for date 2024-11-15.
# Processed game 0022400019 for date 2024-11-15.
# Processed game 0022400020 for date 2024-11-15.
# Processing games for 2024-11-16...
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:36:13 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 05:36:44 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 05:37:16 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 05:37:50 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 05:38:29 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 05:39:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 05:40:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 05:41:51 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 05:44:30 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 05:49:16 03/28/25 Eastern Daylight Time
# Processed game 0022400229 for date 2024-11-16.
# Processed game 0022400230 for date 2024-11-16.
# Processed game 0022400231 for date 2024-11-16.
# Processed game 0022400232 for date 2024-11-16.
# Processed game 0022400233 for date 2024-11-16.
# Processing games for 2024-11-17...
# Processed game 0022400234 for date 2024-11-17.
# Processed game 0022400235 for date 2024-11-17.
# Processed game 0022400236 for date 2024-11-17.
# Processed game 0022400237 for date 2024-11-17.
# Processed game 0022400238 for date 2024-11-17.
# Processed game 0022400239 for date 2024-11-17.
# Processed game 0022400240 for date 2024-11-17.
# Processed game 0022400241 for date 2024-11-17.
# Error processing stats for game 0022400242: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Trying Again
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:58:57 03/28/25 Eastern Daylight Time
# Processed game 0022400242 for date 2024-11-17.
# Processed game 0022400243 for date 2024-11-17.
# Processing games for 2024-11-18...
# Processed game 0022400244 for date 2024-11-18.
# Processed game 0022400245 for date 2024-11-18.
# Processed game 0022400246 for date 2024-11-18.
# Processed game 0022400247 for date 2024-11-18.
# Processed game 0022400248 for date 2024-11-18.
# Processed game 0022400249 for date 2024-11-18.
# Processed game 0022400250 for date 2024-11-18.
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 05:59:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 06:00:05 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 06:00:38 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 06:01:12 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 06:01:50 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 06:02:36 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 06:03:39 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 06:05:13 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 06:07:51 03/28/25 Eastern Daylight Time
# Processed game 0022400251 for date 2024-11-18.
# Processing games for 2024-11-19...
# Processed game 0022400021 for date 2024-11-19.
# ...
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 11:41:20 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 11:41:52 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 4s...
# 11:42:21 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 11:42:56 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 11:43:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 32s...
# 11:44:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 11:45:20 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 11:46:55 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 11:49:33 03/28/25 Eastern Daylight Time
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 11:54:19 03/28/25 Eastern Daylight Time
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 11:54:43 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 11:55:15 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 11:55:48 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 11:56:22 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 11:57:01 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 11:57:48 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 64s...
# 11:58:47 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 12:00:21 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 12:03:00 03/28/25 Eastern Daylight Time
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 12:07:48 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 12:08:19 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 12:08:52 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 12:09:27 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 12:10:05 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 12:10:52 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 64s...
# 12:11:46 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 12:13:21 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 12:16:00 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 12:20:46 03/28/25 Eastern Daylight Time
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 12:29:46 03/28/25 Eastern Daylight Time
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error processing stats for game 0022401067: index 0 is out of bounds for axis 0 with size 0. Trying Again
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 12:30:18 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 12:30:49 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 12:31:22 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 12:31:56 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 12:32:34 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 32s...
# 12:33:17 03/28/25 Eastern Daylight Time
# Error inside retry fn: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 64s...
# 12:34:16 03/28/25 Eastern Daylight Time
# Error inside retry fn: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 12:35:50 03/28/25 Eastern Daylight Time
