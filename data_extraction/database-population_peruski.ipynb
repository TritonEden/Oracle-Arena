# %%
import pandas as pd
from datetime import date, timedelta
import nba_api.stats.endpoints as endpoints
from nba_api.live.nba.endpoints import boxscore

# %% [markdown]
# ### Helper Functions
# - Testing for these functions in data_extraction/nba-api-demo.ipynb

# %%
from nba_api.stats.endpoints import boxscoresummaryv2

def get_home_away_team(game_id):
    """
    Retrieves the home and away team IDs for a given NBA game.

    Parameters:
    game_id (str): The unique identifier for the game.

    Returns:
    tuple: A pair of integers representing the home team ID and away team ID.
    """

    boxscore = boxscoresummaryv2.BoxScoreSummaryV2(game_id=game_id)
    game_data = boxscore.get_data_frames()[0]  # Game summary data

    home_team_id = game_data['HOME_TEAM_ID'].iloc[0]  # Extract home team ID
    away_team_id = game_data['VISITOR_TEAM_ID'].iloc[0]  # Extract away team ID

    return home_team_id, away_team_id

# %%
def get_season(game_id):
    """
    Determines the NBA season based on the given game_id.

    The game_id follows a pattern where:
    - A game_id starting with '00246' to '00299' corresponds to seasons from 1946-47 to 1999-00.
    - A game_id starting with '00200' to '00224' corresponds to seasons from 2000-01 to 2024-25.

    Logic:
    - Extract the 4th and 5th digits of game_id (game_year).
    - If game_year is between 46 and 99, it belongs to the 1900s (1946-47 to 1999-00).
    - Otherwise, it belongs to the 2000s (2000-01 onward).
    - The output is formatted as "YYYY-YY", where YY represents the last two digits of the next year.

    Parameters:
    game_id (str): The unique identifier for the game.

    Returns:
    string: The NBA season in the format 'YYYY-YY' (e.g., '1999-00').
    """

    game_year = int(game_id[3:5])  # Extracts the season identifier
    if 46 <= game_year <= 99:
        start_year = game_year + 1900
    else:
        start_year = game_year + 2000

    end_year_short = (start_year + 1) % 100  # Get last two digits of the next year
    return f"{start_year}-{end_year_short:02d}"

# %% [markdown]
# ### Populating the Teams Table

# %%
def fill_teams_df(game_id, team_stats, teams_df):

    season_year = get_season(game_id)
    team_ids = team_stats['TEAM_ID'].unique()

    # Get home team data
    team_one_row = team_stats[team_stats['TEAM_ID'] == team_ids[0]].iloc[0]
    team_one_location = team_one_row['TEAM_CITY']
    team_one_name = team_one_row['TEAM_NAME']
    team_one_abbrev = team_one_row['TEAM_ABBREVIATION']

    # Get away team data
    team_two_row = team_stats[team_stats['TEAM_ID'] == team_ids[1]].iloc[0]
    team_two_location = team_two_row['TEAM_CITY']
    team_two_name = team_two_row['TEAM_NAME']
    team_two_abbrev = team_two_row['TEAM_ABBREVIATION']

    # Convert the data to a data frame and concatenate it with the existing teams_df
    new_rows = pd.DataFrame([
        {'team_id': team_ids[0], 'season_year': season_year,
        'team_location': team_one_location, 'team_name': team_one_name,
        'team_abbreviation': team_one_abbrev},

        {'team_id': team_ids[1], 'season_year': season_year,
        'team_location': team_two_location, 'team_name': team_two_name,
        'team_abbreviation': team_two_abbrev}
    ])

    # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
    existing_keys = set(zip(teams_df['team_id'], teams_df['season_year']))
    new_rows_filtered = new_rows[~new_rows.apply(lambda row: (row['team_id'], row['season_year']) in existing_keys, axis=1)]

    # Concatenate only if new unique rows exist
    if not new_rows_filtered.empty:
        teams_df = pd.concat([teams_df, new_rows_filtered], ignore_index=True)

    return teams_df

# %%
def fill_players_df(player_stats, players_df):

    player_ids = player_stats['PLAYER_ID'].unique()

    for player_id in player_ids:
        # Get the player data
        player_row = player_stats[player_stats['PLAYER_ID'] == player_id].iloc[0]
        full_name = player_row['PLAYER_NAME']
        name_parts = full_name.split(" ", 1)  # Split at the first space
        player_first_name = name_parts[0]  # First name (everything before the first space)
        player_last_name = name_parts[1] if len(name_parts) > 1 else ""  # Last name (everything after), or empty if no space

        # Convert the data to a data frame and concatenate it with the existing players_df
        new_row = pd.DataFrame([
            {'player_id': player_id,
            'player_first_name': player_first_name, 'player_last_name': player_last_name
            },
        ])

        # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
        existing_keys = set(zip(players_df['player_id']))
        new_rows_filtered = new_row[~new_row.apply(lambda row: (row['player_id']) in existing_keys, axis=1)]

        # Concatenate only if new unique rows exist
        if not new_rows_filtered.empty:
            players_df = pd.concat([players_df, new_rows_filtered], ignore_index=True)

    return players_df

# %%
def fill_games_df(game_id, game_date, games_df):
    season_year = get_season(game_id)
    home_team_id, away_team_id = get_home_away_team(game_id)

    # Convert the data to a data frame and concatenate it with the existing games_df
    new_row = pd.DataFrame([
        {'game_id': game_id, 'season_year': season_year, 'game_date': game_date,
        'home_team_id': home_team_id, 'away_team_id': away_team_id}
    ])

    # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
    existing_keys = set(zip(games_df['game_id'], games_df['season_year']))
    new_rows_filtered = new_row[~new_row.apply(lambda row: (row['game_id'], row['season_year']) in existing_keys, axis=1)]

    # Concatenate only if new unique rows exist
    if not new_rows_filtered.empty:
        games_df = pd.concat([games_df, new_rows_filtered], ignore_index=True)

    return games_df

# %%
def get_player_game_stats(game_id, player_stats, player_game_stats_df):
    player_ids = player_stats['PLAYER_ID'].unique()

    columns_to_keep = [
        "MIN", "FGM", "FGA", "FG_PCT", "FG3M", "FG3A", "FG3_PCT", 
        "FTM", "FTA", "FT_PCT", "OREB", "DREB", "REB", "AST", "STL", 
        "BLK", "TO", "PF", "PTS", "PLUS_MINUS"
    ]

    for player_id in player_ids:
        player_row = player_stats[player_stats['PLAYER_ID'] == player_id].iloc[0]

        # Get the player stats in JSON format
        player_stats_json = player_row.to_dict()

        # Filter the data
        player_stats_json = [
            {key: player_stats_json[key] for key in columns_to_keep if key in player_stats_json} 
        ]

        # Convert the data to a data frame and concatenate it with the existing player_game_stats_df
        new_row = pd.DataFrame([
            {'game_id': game_id, 'player_id': player_id, 'team_id': player_row['TEAM_ID'], 
            'player_game_stats': player_stats_json}
        ])

        # Ensure uniqueness before concatenation (set lookup is O(1) time complexity)
        existing_keys = set(zip(player_game_stats_df['game_id'], player_game_stats_df['player_id']))
        new_rows_filtered = new_row[~new_row.apply(lambda row: (row['game_id'], row['player_id']) in existing_keys, axis=1)]

        # Concatenate only if new unique rows exist
        if not new_rows_filtered.empty:
            player_game_stats_df = pd.concat([player_game_stats_df, new_rows_filtered], ignore_index=True)

    return player_game_stats_df

# %%
import time
import random
from datetime import date, timedelta
import pandas as pd

# Initialize DataFrames
teams_df = pd.DataFrame(columns=['team_id', 'season_year', 'team_location', 'team_name', 'team_abbreviation'])
players_df = pd.DataFrame(columns=['player_id', 'player_first_name', 'player_last_name'])
games_df = pd.DataFrame(columns=['game_id', 'season_year', 'game_date', 'home_team_id', 'away_team_id'])
player_game_stats_df = pd.DataFrame(columns=['game_id', 'player_id', 'team_id', 'player_game_stats'])

start_date = date(11, 1, 1946)
end_date = date(10, 15, 2018)

current_date = start_date
current_highest_season = ""

# Function to simulate an API request with retries and exponential backoff
def fetch_with_retry(func, *args, **kwargs):
    retries = 20  # Number of retries
    delay = 1  # Initial delay time in seconds
    for attempt in range(retries):
        try:
            # Call the original function with passed arguments and keyword arguments
            return func(*args, **kwargs)
        except Exception as e:
            if attempt < retries - 1:
                print(f"Error: {e}. Retrying in {delay}s...")
                #print the current time
                print(time.strftime('%X %x %Z'))
                time.sleep(delay)
                delay *= 2  # Exponential backoff
            else:
                print(f"Failed after {retries} attempts: {e}")
                return None

# Request limit settings
delay_between_requests = 1  # Start with a 60-second delay (1 request per minute)
max_delay = 360  # Maximum delay of 6 minutes (to prevent overwhelming the server)

while current_date <= end_date:
    print(f"Processing games for {current_date}...")
    
    # Add a random sleep time to avoid hitting rate limits
    time.sleep(random.uniform(1.0, 2.0))
    
    # Fetch the games data with retry and exponential backoff
    games = fetch_with_retry(endpoints.scoreboardv2.ScoreboardV2, game_date=current_date)
    
    if games is None:
        # If the fetch failed after retries, skip this date
        start_date += timedelta(days=1)
        continue
    
    try:
        games_data = games.get_data_frames()[0]
        game_ids = games_data['GAME_ID']
        if len(game_ids) > 0:
            current_highest_season = get_season(game_ids[0])  # Assuming get_season is defined somewhere
        else:
            print(f"No games found for {current_date}")
    except Exception as e:
        print(f"Error processing games for {current_date}: {e}. Skipping")
        start_date += timedelta(days=1)
        continue
    
    # Loop through all the game IDs and fetch the box score data
    for game_id in game_ids:
        # Get all stats using BoxScoreTraditionalV2 with retry and exponential backoff
        boxscore = fetch_with_retry(endpoints.boxscoretraditionalv2.BoxScoreTraditionalV2, game_id=game_id)
        
        if boxscore is None:
            print(f"Error fetching stats for game {game_id}. Skipping.")
            start_date += timedelta(days=1)
            continue

        try:
            player_stats = boxscore.get_data_frames()[0]
            team_stats = boxscore.get_data_frames()[1]
            
            teams_df = fill_teams_df(game_id, team_stats, teams_df)
            players_df = fill_players_df(player_stats, players_df)
            games_df = fill_games_df(game_id, current_date, games_df)
            player_game_stats_df = get_player_game_stats(game_id, player_stats, player_game_stats_df)

            teams_df.to_csv(f'teams-old.csv', index=False)
            players_df.to_csv(f'players-old.csv', index=False)
            games_df.to_csv(f'games-old.csv', index=False)
            player_game_stats_df.to_csv(f'player_game_stats-old.csv', index=False)


        except Exception as e:
            print(f"Error processing stats for game {game_id}: {e}. Skipping.")
            start_date += timedelta(days=1)
            continue

    # After processing all games, move to the next 5 days

    # Implement request throttling based on rate limits
    time.sleep(delay_between_requests + random.uniform(0, 1))  # Adding a bit of randomness to avoid clustered requests

    # Apply exponential backoff: increase delay after each request to manage rate limits
    delay_between_requests = min(delay_between_requests, max_delay)

print(teams_df)
print('\n')
print(players_df)
print('\n')
print(games_df)
print('\n')
print(player_game_stats_df)
# Out:
# Processing games for 2018-10-16...
# Current highest season: 2018-19
# Processing games for 2018-10-17...
# Current highest season: 2018-19
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:05:21 03/07/25 Eastern Standard Time
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error processing stats for game 0021800253: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:06:27 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:06:59 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:07:31 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:08:05 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 18:08:43 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 18:09:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 18:10:31 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 18:12:06 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 18:14:44 03/07/25 Eastern Standard Time
# Error processing stats for game 0021800261: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:19:59 03/07/25 Eastern Standard Time
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 18:20:31 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:21:02 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:21:35 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:22:09 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 16s...
# 18:22:38 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 18:23:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 18:24:27 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 18:26:01 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 18:28:39 03/07/25 Eastern Standard Time
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:33:30 03/07/25 Eastern Standard Time
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error processing stats for game 0021800258: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:34:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:35:00 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:35:32 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:36:06 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 18:36:45 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 18:37:31 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 18:38:33 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 128s...
# 18:40:04 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 18:42:42 03/07/25 Eastern Standard Time
# Processing games for 2018-11-21...
# Current highest season: 2018-19
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 18:47:26 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:47:57 03/07/25 Eastern Standard Time
# Processing games for 2018-11-22...
# No games found for 2018-11-22
# Processing games for 2018-11-23...
# Current highest season: 2018-19
# Processing games for 2018-11-24...
# Current highest season: 2018-19
# Processing games for 2018-11-25...
# Current highest season: 2018-19
# Processing games for 2018-12-04...
# Current highest season: 2018-19
# Processing games for 2018-12-05...
# Current highest season: 2018-19
# Processing games for 2018-12-06...
# Current highest season: 2018-19
# Processing games for 2018-12-07...
# Current highest season: 2018-19
# Processing games for 2018-12-08...
# Current highest season: 2018-19
# Processing games for 2018-12-09...
# Current highest season: 2018-19
# Processing games for 2018-12-10...
# Current highest season: 2018-19
# Processing games for 2018-12-11...
# Current highest season: 2018-19
# Processing games for 2018-12-12...
# Current highest season: 2018-19
# Processing games for 2018-12-13...
# Current highest season: 2018-19
# Processing games for 2018-12-14...
# Current highest season: 2018-19
# Processing games for 2018-12-15...
# Current highest season: 2018-19
# Processing games for 2018-12-16...
# Current highest season: 2018-19
# Processing games for 2018-12-17...
# Current highest season: 2018-19
# Processing games for 2018-12-18...
# Current highest season: 2018-19
# Processing games for 2018-12-19...
# Current highest season: 2018-19
# Processing games for 2018-12-20...
# Current highest season: 2018-19
# Processing games for 2018-12-21...
# Current highest season: 2018-19
# Processing games for 2018-12-22...
# Current highest season: 2018-19
# Processing games for 2018-12-23...
# Current highest season: 2018-19
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error processing stats for game 0021800781: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:57:54 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:58:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:58:57 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:59:31 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 19:00:09 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 19:00:56 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 19:01:58 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 19:03:32 03/07/25 Eastern Standard Time
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error processing stats for game 0021800785: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error processing stats for game 0021800785: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Processing games for 2019-02-02...
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 19:07:34 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 2s...
# 19:08:02 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 19:08:34 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 19:09:08 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 19:09:47 03/07/25 Eastern Standard Time
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 19:10:35 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 19:11:06 03/07/25 Eastern Standard Time
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error processing stats for game 0021800784: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 19:12:14 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 19:12:45 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 19:13:17 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 19:13:51 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 19:14:30 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 19:15:16 03/07/25 Eastern Standard Time
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 19:16:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 19:16:56 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 19:17:28 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 19:18:02 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 19:18:40 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 19:19:27 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 19:20:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 19:22:03 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 19:24:41 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 19:29:27 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 19:38:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 19:56:04 03/07/25 Eastern Standard Time
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error processing stats for game 0021800785: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 20:31:40 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 20:32:12 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 20:32:44 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 20:33:18 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 16s...
# 20:33:53 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 20:34:39 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 20:35:41 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 128s...
# 20:37:06 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 20:39:45 03/07/25 Eastern Standard Time
# Processing games for 2019-02-02...
# Current highest season: 2018-19
# Processing games for 2019-02-03...
# Current highest season: 2018-19
# Processing games for 2019-02-04...
# Current highest season: 2018-19
# Processing games for 2019-02-05...
# Current highest season: 2018-19
# Processing games for 2019-02-06...
# Current highest season: 2018-19
# Processing games for 2019-02-07...
# Current highest season: 2018-19
# Processing games for 2019-02-08...
# Current highest season: 2018-19
# Processing games for 2019-02-09...
# Current highest season: 2018-19
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 20:47:52 03/07/25 Eastern Standard Time
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 20:48:34 03/07/25 Eastern Standard Time
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 20:49:13 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 20:49:44 03/07/25 Eastern Standard Time
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 20:50:30 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 20:51:02 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 20:51:34 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 20:52:08 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 20:52:46 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 20:53:32 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 20:54:34 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 20:56:08 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 20:58:47 03/07/25 Eastern Standard Time
# Processing games for 2019-02-23...
# Current highest season: 2018-19
# Error processing stats for game 0021800892: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 21:04:08 03/07/25 Eastern Standard Time
# Processing games for 2019-02-24...
# Current highest season: 2018-19
# Processing games for 2019-02-25...
# Current highest season: 2018-19
# Processing games for 2019-02-26...
# Current highest season: 2018-19
# Processing games for 2019-02-27...
# Current highest season: 2018-19
# Processing games for 2019-02-28...
# Current highest season: 2018-19
# Processing games for 2019-03-01...
# Current highest season: 2018-19
# Processing games for 2019-03-02...
# Current highest season: 2018-19
# Processing games for 2019-03-03...
# Current highest season: 2018-19
# Processing games for 2019-03-04...
# Current highest season: 2018-19
# Processing games for 2019-03-05...
# Current highest season: 2018-19
# Processing games for 2019-03-06...
# Current highest season: 2018-19
# Processing games for 2019-03-07...
# Current highest season: 2018-19
# Processing games for 2019-04-20...
# Current highest season: 2018-19
# Processing games for 2019-04-21...
# Current highest season: 2018-19
# Processing games for 2019-04-22...
# Current highest season: 2018-19
# Processing games for 2019-04-23...
# Current highest season: 2018-19
# Processing games for 2019-04-24...
# Current highest season: 2018-19
# Error processing stats for game 0041800145: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Processing games for 2019-04-25...
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 21:10:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 21:11:00 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 21:11:32 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 21:12:06 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 21:12:44 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 21:13:30 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 21:14:33 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 21:16:07 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 21:18:45 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 21:23:31 03/07/25 Eastern Standard Time
# Current highest season: 2018-19
# Processing games for 2019-04-26...
# Current highest season: 2018-19
# Processing games for 2019-04-27...
# Current highest season: 2018-19
# Processing games for 2019-04-28...
# Current highest season: 2018-19
# Processing games for 2019-04-29...
# Current highest season: 2018-19
# Processing games for 2019-04-30...
# Current highest season: 2018-19
# Processing games for 2019-05-01...
# Current highest season: 2018-19
# Processing games for 2019-05-02...
# Current highest season: 2018-19
# Processing games for 2019-05-03...
# Current highest season: 2018-19
# Processing games for 2019-05-04...
# Current highest season: 2018-19
# Processing games for 2019-07-07...
# No games found for 2019-07-07
# Processing games for 2019-07-08...
# No games found for 2019-07-08
# Processing games for 2019-07-09...
# No games found for 2019-07-09
# Processing games for 2019-07-10...
# No games found for 2019-07-10
# Processing games for 2019-07-11...
# No games found for 2019-07-11
# Processing games for 2019-07-12...
# No games found for 2019-07-12
# Processing games for 2019-07-13...
# No games found for 2019-07-13
# Processing games for 2019-07-14...
# No games found for 2019-07-14
# Processing games for 2019-07-15...
# No games found for 2019-07-15
# Processing games for 2019-07-16...
# No games found for 2019-07-16
# Processing games for 2019-07-17...
# No games found for 2019-07-17
# Processing games for 2019-07-18...
# No games found for 2019-07-18
# Processing games for 2019-07-19...
# No games found for 2019-07-19
# Processing games for 2019-07-20...
# No games found for 2019-07-20
# Processing games for 2019-07-21...
# No games found for 2019-07-21
# Processing games for 2019-07-22...
# No games found for 2019-07-22
# Processing games for 2019-07-23...
# No games found for 2019-07-23
# Processing games for 2019-07-24...
# No games found for 2019-07-24
# Processing games for 2019-07-25...
# No games found for 2019-07-25
# Processing games for 2019-11-15...
# Current highest season: 2019-20
# Processing games for 2019-11-16...
# Current highest season: 2019-20
# Processing games for 2019-11-17...
# Current highest season: 2019-20
# Processing games for 2019-11-18...
# Current highest season: 2019-20
# Error processing stats for game 0021900195: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 21:37:21 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 21:37:53 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 21:38:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 21:38:59 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 21:39:37 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 21:40:23 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 21:41:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 21:43:00 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 21:45:38 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 21:50:24 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 21:59:26 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 22:17:00 03/07/25 Eastern Standard Time
# Processing games for 2019-11-19...
# Current highest season: 2019-20
# Processing games for 2019-11-20...
# Current highest season: 2019-20
# Processing games for 2019-11-21...
# Current highest season: 2019-20
# Processing games for 2019-11-22...
# Current highest season: 2019-20
# Processing games for 2019-11-23...
# Current highest season: 2019-20
# Processing games for 2019-11-24...
# Current highest season: 2019-20
# Processing games for 2019-11-25...
# Current highest season: 2019-20
# Processing games for 2019-11-26...
# Current highest season: 2019-20
# Processing games for 2019-11-27...
# Current highest season: 2019-20
# Processing games for 2019-11-28...
# No games found for 2019-11-28
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 22:55:49 03/07/25 Eastern Standard Time
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Error processing stats for game 0021900327: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 22:57:06 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 2s...
# 22:57:28 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 22:58:01 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 8s...
# 22:58:26 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 22:59:04 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 22:59:50 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 23:00:53 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 128s...
# 23:02:23 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 23:05:01 03/07/25 Eastern Standard Time
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Error processing stats for game 0021900329: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Skipping.
# Processing games for 2019-12-06...
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 23:10:25 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:10:56 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:11:28 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 23:12:02 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 23:12:40 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 23:13:27 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 23:14:29 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 128s...
# 23:15:59 03/07/25 Eastern Standard Time
# Current highest season: 2019-20
# Processing games for 2019-12-06...
# Current highest season: 2019-20
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 23:18:44 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:19:16 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:19:48 03/07/25 Eastern Standard Time
# Processing games for 2019-12-07...
# Current highest season: 2019-20
# Processing games for 2019-12-08...
# Current highest season: 2019-20
# Processing games for 2019-12-09...
# Current highest season: 2019-20
# Processing games for 2019-12-10...
# Current highest season: 2019-20
# Processing games for 2019-12-11...
# Current highest season: 2019-20
# Processing games for 2019-12-12...
# Current highest season: 2019-20
# Processing games for 2019-12-13...
# Current highest season: 2019-20
# Processing games for 2019-12-14...
# Current highest season: 2019-20
# Processing games for 2019-12-15...
# Current highest season: 2019-20
# Processing games for 2019-12-16...
# Current highest season: 2019-20
# Processing games for 2019-12-17...
# Current highest season: 2019-20
# Processing games for 2019-12-18...
# Current highest season: 2019-20
# Processing games for 2019-12-19...
# Current highest season: 2019-20
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 23:25:58 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:26:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:27:01 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 23:27:35 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 16s...
# 23:28:10 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 23:28:56 03/07/25 Eastern Standard Time
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 23:30:13 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:30:44 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:31:17 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 23:31:51 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 23:32:29 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 23:33:15 03/07/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 64s...
# 23:34:14 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 23:35:48 03/07/25 Eastern Standard Time
# Processing games for 2020-01-28...
# Current highest season: 2019-20
# Processing games for 2020-01-29...
# Current highest season: 2019-20
# Error processing stats for game 0021900712: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 23:39:22 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:39:53 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:40:26 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 23:41:00 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 23:41:38 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 23:42:24 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 23:43:26 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 23:45:01 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 23:47:39 03/07/25 Eastern Standard Time
# Processing games for 2020-01-30...
# Current highest season: 2019-20
# Processing games for 2020-01-31...
# Current highest season: 2019-20
# Processing games for 2020-02-01...
# Current highest season: 2019-20
# Processing games for 2020-02-02...
# Current highest season: 2019-20
# Processing games for 2020-02-03...
# Current highest season: 2019-20
# Processing games for 2020-02-04...
# Current highest season: 2019-20
# Processing games for 2020-02-05...
# Current highest season: 2019-20
# Processing games for 2020-02-06...
# Current highest season: 2019-20
# Processing games for 2020-02-07...
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 23:55:38 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 23:56:09 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 23:56:41 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 23:57:15 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 23:57:53 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 23:58:39 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 23:59:41 03/07/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 00:01:16 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 00:03:54 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 00:08:40 03/08/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1024s...
# 00:17:38 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 00:35:13 03/08/25 Eastern Standard Time
# Current highest season: 2019-20
# Processing games for 2020-02-08...
# Current highest season: 2019-20
# Processing games for 2020-02-22...
# Current highest season: 2019-20
# Processing games for 2020-02-22...
# Current highest season: 2019-20
# Processing games for 2020-02-22...
# Current highest season: 2019-20
# Processing games for 2020-02-22...
# Current highest season: 2019-20
# Processing games for 2020-02-23...
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 01:11:24 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 01:11:55 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 01:12:27 03/08/25 Eastern Standard Time
# Current highest season: 2019-20
# Processing games for 2020-02-24...
# Current highest season: 2019-20
# Processing games for 2020-02-25...
# Current highest season: 2019-20
# Processing games for 2020-02-26...
# Current highest season: 2019-20
# Processing games for 2020-02-27...
# Current highest season: 2019-20
# Processing games for 2020-02-28...
# Current highest season: 2019-20
# Processing games for 2020-02-29...
# Current highest season: 2019-20
# Processing games for 2020-03-01...
# Current highest season: 2019-20
# Processing games for 2020-03-02...
# Current highest season: 2019-20
# Processing games for 2020-03-03...
# Current highest season: 2019-20
# Processing games for 2020-03-04...
# Current highest season: 2019-20
# Processing games for 2020-03-05...
# Current highest season: 2019-20
# Processing games for 2020-03-06...
# Current highest season: 2019-20
# Processing games for 2020-03-07...
# Current highest season: 2019-20
# Processing games for 2020-03-08...
# Current highest season: 2019-20
# Processing games for 2020-03-09...
# Current highest season: 2019-20
# Processing games for 2020-09-19...
# Current highest season: 2019-20
# Processing games for 2020-09-20...
# Current highest season: 2019-20
# Processing games for 2020-09-21...
# No games found for 2020-09-21
# Processing games for 2020-09-22...
# Current highest season: 2019-20
# Processing games for 2020-09-23...
# Current highest season: 2019-20
# Processing games for 2020-09-24...
# Current highest season: 2019-20
# Processing games for 2020-09-25...
# Current highest season: 2019-20
# Processing games for 2020-09-26...
# Current highest season: 2019-20
# Processing games for 2020-09-27...
# Current highest season: 2019-20
# Processing games for 2020-09-28...
# No games found for 2020-09-28
# Processing games for 2020-09-29...
# No games found for 2020-09-29
# Processing games for 2020-09-30...
# Current highest season: 2019-20
# Processing games for 2020-12-14...
# Current highest season: 2020-21
# Processing games for 2020-12-15...
# Current highest season: 2020-21
# Processing games for 2020-12-16...
# Current highest season: 2020-21
# Processing games for 2020-12-17...
# Current highest season: 2020-21
# Processing games for 2020-12-18...
# Current highest season: 2020-21
# Processing games for 2020-12-19...
# Current highest season: 2020-21
# Processing games for 2020-12-20...
# No games found for 2020-12-20
# Processing games for 2020-12-21...
# No games found for 2020-12-21
# Processing games for 2020-12-22...
# Current highest season: 2020-21
# Processing games for 2020-12-23...
# Current highest season: 2020-21
# Processing games for 2020-12-24...
# No games found for 2020-12-24
# Processing games for 2020-12-25...
# Current highest season: 2020-21
# Processing games for 2020-12-26...
# Current highest season: 2020-21
# Processing games for 2020-12-27...
# Current highest season: 2020-21
# Processing games for 2020-12-28...
# Current highest season: 2020-21
# Processing games for 2020-12-29...
# Current highest season: 2020-21
# Processing games for 2020-12-30...
# Current highest season: 2020-21
# Processing games for 2020-12-31...
# Current highest season: 2020-21
# Processing games for 2021-02-08...
# Current highest season: 2020-21
# Error processing stats for game 0022000371: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 01:28:23 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 01:28:54 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 01:29:26 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 01:30:00 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 01:30:39 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 01:31:25 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 01:32:27 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 01:34:01 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 01:36:39 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 01:41:25 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 01:50:28 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 02:08:02 03/08/25 Eastern Standard Time
# Processing games for 2021-02-08...
# Current highest season: 2020-21
# Processing games for 2021-02-08...
# Current highest season: 2020-21
# Processing games for 2021-02-09...
# Current highest season: 2020-21
# Processing games for 2021-02-10...
# Current highest season: 2020-21
# Processing games for 2021-02-11...
# Current highest season: 2020-21
# Processing games for 2021-02-12...
# Current highest season: 2020-21
# Processing games for 2021-02-13...
# Current highest season: 2020-21
# Processing games for 2021-02-14...
# Current highest season: 2020-21
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 02:45:19 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 02:45:51 03/08/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 4s...
# 02:46:20 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 02:46:54 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 02:47:32 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 02:48:18 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 02:49:20 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 02:50:54 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 02:53:32 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 02:58:19 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 03:07:21 03/08/25 Eastern Standard Time
# Processing games for 2021-02-15...
# Current highest season: 2020-21
# Processing games for 2021-02-16...
# Current highest season: 2020-21
# Processing games for 2021-02-17...
# Current highest season: 2020-21
# Processing games for 2021-02-18...
# Current highest season: 2020-21
# Processing games for 2021-02-19...
# Current highest season: 2020-21
# Processing games for 2021-02-27...
# Current highest season: 2020-21
# Processing games for 2021-02-27...
# Current highest season: 2020-21
# Processing games for 2021-02-27...
# Current highest season: 2020-21
# Processing games for 2021-02-28...
# Current highest season: 2020-21
# Processing games for 2021-03-01...
# Current highest season: 2020-21
# Processing games for 2021-03-02...
# Current highest season: 2020-21
# Processing games for 2021-03-03...
# Current highest season: 2020-21
# Processing games for 2021-03-04...
# Current highest season: 2020-21
# Processing games for 2021-03-05...
# No games found for 2021-03-05
# Processing games for 2021-03-06...
# No games found for 2021-03-06
# Processing games for 2021-03-07...
# Current highest season: 2020-21
# Processing games for 2021-03-08...
# No games found for 2021-03-08
# Processing games for 2021-03-09...
# No games found for 2021-03-09
# Processing games for 2021-03-10...
# Current highest season: 2020-21
# Processing games for 2021-03-11...
# Current highest season: 2020-21
# Processing games for 2021-03-12...
# Current highest season: 2020-21
# Processing games for 2021-03-13...
# Current highest season: 2020-21
# Processing games for 2021-03-14...
# Current highest season: 2020-21
# Processing games for 2021-03-15...
# Current highest season: 2020-21
# Processing games for 2021-04-20...
# Current highest season: 2020-21
# Processing games for 2021-04-20...
# Current highest season: 2020-21
# Processing games for 2021-04-20...
# Current highest season: 2020-21
# Processing games for 2021-04-21...
# Current highest season: 2020-21
# Processing games for 2021-04-22...
# Current highest season: 2020-21
# ...
# 17:00:46 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 17:03:24 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 17:08:10 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 17:17:13 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 17:34:47 03/08/25 Eastern Standard Time
# Processing games for 2024-04-07...
# Current highest season: 2023-24
# Processing games for 2024-04-08...
# No games found for 2024-04-08
# Processing games for 2024-04-09...
# Current highest season: 2023-24
# Processing games for 2024-04-10...
# Current highest season: 2023-24
# Processing games for 2024-04-11...
# Current highest season: 2023-24
# Processing games for 2024-04-25...
# Current highest season: 2023-24
# Processing games for 2024-04-26...
# Current highest season: 2023-24
# Processing games for 2024-04-27...
# Current highest season: 2023-24
# Processing games for 2024-04-28...
# Current highest season: 2023-24
# Error processing stats for game 0042300164: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Processing games for 2024-04-29...
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 18:14:51 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 18:15:23 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 18:15:55 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 18:16:29 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 18:17:07 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 18:17:53 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 18:18:55 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 18:20:29 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 18:23:08 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 18:27:54 03/08/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1024s...
# 18:36:53 03/08/25 Eastern Standard Time
# Current highest season: 2023-24
# Processing games for 2024-04-30...
# Current highest season: 2023-24
# Processing games for 2024-05-01...
# Current highest season: 2023-24
# Processing games for 2024-05-02...
# Current highest season: 2023-24
# Processing games for 2024-05-03...
# Current highest season: 2023-24
# Processing games for 2024-05-04...
# Current highest season: 2023-24
# Processing games for 2024-05-05...
# Current highest season: 2023-24
# Processing games for 2024-05-06...
# Current highest season: 2023-24
# Processing games for 2024-05-07...
# Current highest season: 2023-24
# Processing games for 2024-05-08...
# Current highest season: 2023-24
# Processing games for 2024-05-09...
# Current highest season: 2023-24
# Processing games for 2024-05-10...
# Current highest season: 2023-24
# Processing games for 2024-05-11...
# Current highest season: 2023-24
# Processing games for 2024-05-12...
# Current highest season: 2023-24
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-06...
# Current highest season: 2024-25
# Processing games for 2024-11-07...
# Current highest season: 2024-25
# Processing games for 2024-11-08...
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 19:01:34 03/08/25 Eastern Standard Time
# Current highest season: 2024-25
# Processing games for 2024-11-09...
# Current highest season: 2024-25
# Processing games for 2024-11-10...
# Current highest season: 2024-25
# Processing games for 2024-11-18...
# Current highest season: 2024-25
# Processing games for 2024-11-18...
# Current highest season: 2024-25
# Processing games for 2024-11-18...
# Current highest season: 2024-25
# Processing games for 2024-11-18...
# Current highest season: 2024-25
# Processing games for 2024-11-19...
# Current highest season: 2024-25
# Processing games for 2024-11-20...
# Current highest season: 2024-25
# Processing games for 2024-11-21...
# Current highest season: 2024-25
# Processing games for 2024-11-22...
# Current highest season: 2024-25
# Processing games for 2024-11-23...
# Current highest season: 2024-25
# Processing games for 2024-11-24...
# Current highest season: 2024-25
# Processing games for 2024-11-25...
# Current highest season: 2024-25
# Processing games for 2024-11-26...
# Current highest season: 2024-25
# Processing games for 2024-11-27...
# Current highest season: 2024-25
# Processing games for 2024-11-28...
# No games found for 2024-11-28
# Processing games for 2024-11-29...
# Current highest season: 2024-25
# Processing games for 2024-11-30...
# Current highest season: 2024-25
# Processing games for 2024-12-01...
# Current highest season: 2024-25
# Processing games for 2024-12-02...
# Current highest season: 2024-25
# Processing games for 2024-12-03...
# Current highest season: 2024-25
# Processing games for 2024-12-04...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Error processing stats for game 0022400580: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Skipping.
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1s...
# 19:17:45 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 19:18:16 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 19:18:48 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 19:19:23 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 19:20:01 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 19:20:47 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 19:21:49 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 19:23:23 03/08/25 Eastern Standard Time
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 256s...
# 19:25:58 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 19:30:44 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 19:39:46 03/08/25 Eastern Standard Time
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Error: ('Connection aborted.', RemoteDisconnected('Remote end closed connection without response')). Retrying in 1s...
# 20:00:01 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2s...
# 20:00:32 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 4s...
# 20:01:04 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 8s...
# 20:01:39 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 16s...
# 20:02:17 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 32s...
# 20:03:03 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 64s...
# 20:04:05 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 128s...
# 20:05:39 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 256s...
# 20:08:17 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 512s...
# 20:13:04 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 1024s...
# 20:22:06 03/08/25 Eastern Standard Time
# Error: HTTPSConnectionPool(host='stats.nba.com', port=443): Read timed out. (read timeout=30). Retrying in 2048s...
# 20:39:40 03/08/25 Eastern Standard Time
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-17...
# Current highest season: 2024-25
# Processing games for 2025-01-18...
# Current highest season: 2024-25
# Processing games for 2025-01-19...
# Current highest season: 2024-25
# Processing games for 2025-01-20...
# Current highest season: 2024-25
# Processing games for 2025-01-21...
# Current highest season: 2024-25
# Processing games for 2025-01-22...
# Current highest season: 2024-25
# Processing games for 2025-01-23...
# Current highest season: 2024-25
# Processing games for 2025-01-31...
# Current highest season: 2024-25
# Processing games for 2025-02-01...
# Current highest season: 2024-25
# Processing games for 2025-02-02...
# Current highest season: 2024-25
# Processing games for 2025-02-03...
# Current highest season: 2024-25
# Processing games for 2025-02-04...
# Current highest season: 2024-25
# Processing games for 2025-02-05...
# Current highest season: 2024-25
# Processing games for 2025-02-06...
# Current highest season: 2024-25
# Processing games for 2025-02-07...
# Current highest season: 2024-25
# Processing games for 2025-02-08...
# Current highest season: 2024-25
# Processing games for 2025-02-09...
# Current highest season: 2024-25
# Processing games for 2025-02-10...
# Current highest season: 2024-25
# Processing games for 2025-02-11...
# Current highest season: 2024-25
# Processing games for 2025-02-12...
# Current highest season: 2024-25
# Processing games for 2025-02-13...
# Current highest season: 2024-25
# Processing games for 2025-02-14...
# No games found for 2025-02-14
# Processing games for 2025-02-15...
# No games found for 2025-02-15
# Processing games for 2025-02-16...
# Current highest season: 2024-25
# Processing games for 2025-02-17...
# No games found for 2025-02-17
# Processing games for 2025-02-18...
# No games found for 2025-02-18
# Processing games for 2025-02-19...
# Current highest season: 2024-25
#         team_id season_year  team_location     team_name team_abbreviation
# 0    1610612755     2018-19   Philadelphia         76ers               PHI
# 1    1610612738     2018-19         Boston       Celtics               BOS
# 2    1610612760     2018-19  Oklahoma City       Thunder               OKC
# 3    1610612744     2018-19   Golden State      Warriors               GSW
# 4    1610612749     2018-19      Milwaukee         Bucks               MIL
# ..          ...         ...            ...           ...               ...
# 213  1610612764     2024-25     Washington       Wizards               WAS
# 214  1610616853     2024-25                  Young Stars               KEN
# 215  1610616851     2024-25                 Global Stars               CHK
# 216  1610616852     2024-25                          OGs               SHQ
# 217  1610616854     2024-25                 Rising Stars               CAN
#
# [218 rows x 5 columns]
#
#
#        player_id player_first_name player_last_name
# 0         203967             Dario            Šarić
# 1         203496            Robert        Covington
# 2         203954              Joel           Embiid
# 3        1628365          Markelle            Fultz
# 4        1627732               Ben          Simmons
# ...          ...               ...              ...
# 109094   1642355            Bronny            James
# 109095   1631132         Christian           Koloko
# 109096   1629003             Shake           Milton
# 109097    202693          Markieff           Morris
# 109098   1629629               Cam          Reddish
#
# [109099 rows x 3 columns]
#
#
#          game_id season_year   game_date home_team_id away_team_id
# 0     0021800001     2018-19  2018-10-16   1610612738   1610612755
# 1     0021800002     2018-19  2018-10-16   1610612744   1610612760
# 2     0021800003     2018-19  2018-10-17   1610612766   1610612749
# 3     0021800004     2018-19  2018-10-17   1610612765   1610612751
# 4     0021800005     2018-19  2018-10-17   1610612754   1610612763
# ...          ...         ...         ...          ...          ...
# 3043  0022401004     2024-25  2025-02-13   1610612762   1610612746
# 3044  0032400011     2024-25  2025-02-16         None         None
# 3045  0032400021     2024-25  2025-02-16         None         None
# 3046  0032400031     2024-25  2025-02-16         None         None
# 3047  0022400524     2024-25  2025-02-19   1610612747   1610612766
#
# [3048 rows x 5 columns]
#
#
#           game_id player_id     team_id  \
# 0      0021800001    203967  1610612755
# 1      0021800001    203496  1610612755
# 2      0021800001    203954  1610612755
# 3      0021800001   1628365  1610612755
# 4      0021800001   1627732  1610612755
# ...           ...       ...         ...
# 79023  0022400524   1642355  1610612747
# 79024  0022400524   1631132  1610612747
# 79025  0022400524   1629003  1610612747
# 79026  0022400524    202693  1610612747
# 79027  0022400524   1629629  1610612747
#
#                                        player_game_stats
# 0      [{'MIN': '22.000000:54', 'FGM': 3.0, 'FGA': 8....
# 1      [{'MIN': '34.000000:13', 'FGM': 3.0, 'FGA': 10...
# 2      [{'MIN': '36.000000:49', 'FGM': 9.0, 'FGA': 21...
# 3      [{'MIN': '24.000000:20', 'FGM': 2.0, 'FGA': 7....
# 4      [{'MIN': '42.000000:44', 'FGM': 7.0, 'FGA': 14...
# ...                                                  ...
# 79023  [{'MIN': None, 'FGM': nan, 'FGA': nan, 'FG_PCT...
# 79024  [{'MIN': None, 'FGM': nan, 'FGA': nan, 'FG_PCT...
# 79025  [{'MIN': None, 'FGM': nan, 'FGA': nan, 'FG_PCT...
# 79026  [{'MIN': None, 'FGM': nan, 'FGA': nan, 'FG_PCT...
# 79027  [{'MIN': None, 'FGM': nan, 'FGA': nan, 'FG_PCT...
#
# [79028 rows x 4 columns]
